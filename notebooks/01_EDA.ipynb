# %% [markdown]
# ## Data Exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12

# %%
file_path = '../data/startup data.csv'
try:
    df = pd.read_csv(file_path)
except FileNotFoundError:
    print(f"ERROR: File not found at '{file_path}'.")
    print("Please ensure you have downloaded 'startup_data.csv' from Kaggle and placed it in the same directory.")
except Exception as e:
    print(f"An error occurred during loading: {e}")

# %%
df
# Out:
#      Unnamed: 0 state_code   latitude   longitude zip_code       id  \
# 0          1005         CA  42.358880  -71.056820    92101   c:6669
# 1           204         CA  37.238916 -121.973718    95032  c:16283
# 2          1001         CA  32.901049 -117.192656    92121  c:65620
# 3           738         CA  37.320309 -122.050040    95014  c:42668
# 4          1002         CA  37.779281 -122.419236    94105  c:65806
# ..          ...        ...        ...         ...      ...      ...
# 918         352         CA  37.740594 -122.376471    94107  c:21343
# 919         721         MA  42.504817  -71.195611     1803  c:41747
# 920         557         CA  37.408261 -122.015920    94089  c:31549
# 921         589         CA  37.556732 -122.288378    94404  c:33198
# 922         462         CA  37.386778 -121.966277    95054  c:26702
#
#               city              Unnamed: 6                  name  labels  ...  \
# 0        San Diego                     NaN           Bandsintown       1  ...
# 1        Los Gatos                     NaN             TriCipher       1  ...
# 2        San Diego      San Diego CA 92121                 Plixi       1  ...
# 3        Cupertino      Cupertino CA 95014     Solidcore Systems       1  ...
# 4    San Francisco  San Francisco CA 94105        Inhale Digital       0  ...
# ..             ...                     ...                   ...     ...  ...
# 918  San Francisco                     NaN               CoTweet       1  ...
# 919     Burlington      Burlington MA 1803    Reef Point Systems       0  ...
# 920      Sunnyvale                     NaN       Paracor Medical       0  ...
# 921  San Francisco                     NaN               Causata       1  ...
# 922    Santa Clara    Santa Clara CA 95054  Asempra Technologies       1  ...
#
#     object_id has_VC has_angel has_roundA  has_roundB  has_roundC  has_roundD  \
# 0      c:6669      0         1          0           0           0           0
# 1     c:16283      1         0          0           1           1           1
# 2     c:65620      0         0          1           0           0           0
# 3     c:42668      0         0          0           1           1           1
# 4     c:65806      1         1          0           0           0           0
# ..        ...    ...       ...        ...         ...         ...         ...
# 918   c:21343      0         0          1           0           0           0
# 919   c:41747      1         0          0           1           0           0
# 920   c:31549      0         0          0           0           0           1
# 921   c:33198      0         0          1           1           0           0
# 922   c:26702      0         0          0           1           0           0
#
#      avg_participants  is_top500    status
# 0              1.0000          0  acquired
# 1              4.7500          1  acquired
# 2              4.0000          1  acquired
# 3              3.3333          1  acquired
# 4              1.0000          1    closed
# ..                ...        ...       ...
# 918            6.0000          1  acquired
# 919            2.6667          1    closed
# 920            8.0000          1    closed
# 921            1.0000          1  acquired
# 922            3.0000          1  acquired
#
# [923 rows x 49 columns]

# %%
df.describe()
# Out:
#         Unnamed: 0    latitude   longitude      labels  \
# count   923.000000  923.000000  923.000000  923.000000
# mean    572.297941   38.517442 -103.539212    0.646804
# std     333.585431    3.741497   22.394167    0.478222
# min       1.000000   25.752358 -122.756956    0.000000
# 25%     283.500000   37.388869 -122.198732    0.000000
# 50%     577.000000   37.779281 -118.374037    1.000000
# 75%     866.500000   40.730646  -77.214731    1.000000
# max    1153.000000   59.335232   18.057121    1.000000
#
#        age_first_funding_year  age_last_funding_year  \
# count              923.000000             923.000000
# mean                 2.235630               3.931456
# std                  2.510449               2.967910
# min                 -9.046600              -9.046600
# 25%                  0.576700               1.669850
# 50%                  1.446600               3.528800
# 75%                  3.575350               5.560250
# max                 21.895900              21.895900
#
#        age_first_milestone_year  age_last_milestone_year  relationships  \
# count                771.000000               771.000000     923.000000
# mean                   3.055353                 4.754423       7.710726
# std                    2.977057                 3.212107       7.265776
# min                  -14.169900                -7.005500       0.000000
# 25%                    1.000000                 2.411000       3.000000
# 50%                    2.520500                 4.476700       5.000000
# 75%                    4.686300                 6.753400      10.000000
# max                   24.684900                24.684900      63.000000
#
#        funding_rounds  ...  is_consulting  is_othercategory      has_VC  \
# count      923.000000  ...     923.000000        923.000000  923.000000
# mean         2.310943  ...       0.003250          0.322860    0.326111
# std          1.390922  ...       0.056949          0.467823    0.469042
# min          1.000000  ...       0.000000          0.000000    0.000000
# 25%          1.000000  ...       0.000000          0.000000    0.000000
# 50%          2.000000  ...       0.000000          0.000000    0.000000
# 75%          3.000000  ...       0.000000          1.000000    1.000000
# max         10.000000  ...       1.000000          1.000000    1.000000
#
#         has_angel  has_roundA  has_roundB  has_roundC  has_roundD  \
# count  923.000000  923.000000  923.000000  923.000000  923.000000
# mean     0.254605    0.508126    0.392199    0.232936    0.099675
# std      0.435875    0.500205    0.488505    0.422931    0.299729
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    1.000000    0.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000
#
#        avg_participants   is_top500
# count        923.000000  923.000000
# mean           2.838586    0.809317
# std            1.874601    0.393052
# min            1.000000    0.000000
# 25%            1.500000    1.000000
# 50%            2.500000    1.000000
# 75%            3.800000    1.000000
# max           16.000000    1.000000
#
# [8 rows x 35 columns]

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0                    0
# state_code                    0
# latitude                      0
# longitude                     0
# zip_code                      0
# id                            0
# city                          0
# Unnamed: 6                  493
# name                          0
# labels                        0
# founded_at                    0
# closed_at                   588
# first_funding_at              0
# last_funding_at               0
# age_first_funding_year        0
# age_last_funding_year         0
# age_first_milestone_year    152
# age_last_milestone_year     152
# relationships                 0
# funding_rounds                0
# funding_total_usd             0
# milestones                    0
# state_code.1                  1
# is_CA                         0
# is_NY                         0
# is_MA                         0
# is_TX                         0
# is_otherstate                 0
# category_code                 0
# is_software                   0
# is_web                        0
# is_mobile                     0
# is_enterprise                 0
# is_advertising                0
# is_gamesvideo                 0
# is_ecommerce                  0
# is_biotech                    0
# is_consulting                 0
# is_othercategory              0
# object_id                     0
# has_VC                        0
# has_angel                     0
# has_roundA                    0
# has_roundB                    0
# has_roundC                    0
# has_roundD                    0
# avg_participants              0
# is_top500                     0
# status                        0
# dtype: int64

# %% [markdown]
# ### Exploring Unnamed: 0
# - it has no null values
# - all values in this column are unique
# - it is probably some sort of identifier

# %%
df["Unnamed: 0"].nunique()
# Out:
# 923

# %%
df["Unnamed: 0"]
# Out:
# 0      1005
# 1       204
# 2      1001
# 3       738
# 4      1002
#        ...
# 918     352
# 919     721
# 920     557
# 921     589
# 922     462
# Name: Unnamed: 0, Length: 923, dtype: int64

# %%
#check if it equals the id column
df["Unnamed: 0"].equals(df["id"])
# Out:
# False

# %% [markdown]
# ### Exploring Unnamed: 6
# - it is cleare that this column contains the locations
# - using regex, it matches the existing columns: zip_code, city and state_code in most cases
# - since it is a duplicated info it can be dropped

# %%
df["Unnamed: 6"].unique()
# Out:
# array([nan, 'San Diego CA 92121', 'Cupertino CA 95014',
#        'San Francisco CA 94105', 'Mountain View CA 94043',
#        'Williamstown MA 1267', 'Vienna VA 22182', 'New York NY 10004',
#        'Chicago IL 60601', 'Berkeley CA 94704', 'Santa Ana CA 92705',
#        'Moffett Field CA 94035', 'Seattle WA 98119',
#        'Pittsburgh PA 15219', 'New York NY 10011', 'San Jose CA 95134',
#        'Manchester NH 3101', 'Sunnyvale CA 94085', 'New York NY 100011',
#        'Cambridge MA 2139', 'San Francisco CA 94607',
#        'South San Francisco CA 94080', 'Boston MA 2210',
#        'Austin TX 78731', 'Waltham MA 2451', 'Palo Alto CA 94301',
#        'Palo Alto CA 95128', 'Wilmington MA 1887',
#        'Kirkland WA 98033-6314', 'Tampa FL 33609', 'Boston MA 02111-1720',
#        'Fremont CA 94538', 'Santa Clara CA 95051',
#        'San Francisco CA 94107', 'Cambridge MA 2138', 'Princeton NJ 8540',
#        'Loveland CO 80538', 'Kearneysville WV 25430',
#        'Mountain View CA 94041', 'San Francisco CA 94110',
#        'Alpharetta GA 30009', 'Seattle WA 98104', 'Bellevue WA 98004',
#        'San Jose CA 95128', 'Chicago IL 60607', 'Milpitas CA 95035-6261',
#        'San Diego CA 92101', 'San Francisco CA 94103',
#        'Burlingame CA 94010', 'New York NY 10001', 'Somerville MA 2143',
#        'New York NY 10003', 'Timonium MD 21093', 'Pittsburgh PA 15213',
#        'Reston VA 20191', 'Chicago IL 60606', 'Palo Alto CA 94303',
#        'Cincinnati OH 45202', 'Atlanta GA 30305', 'Sterling VA 20166',
#        'Oakland CA 94609', 'Boston MA 2109', 'Centennial CO 80112',
#        'Chicago IL 60631', 'Memphis TN 38103-4717', 'New York NY 10013',
#        'Plymouth MN 55441', 'San Francisco CA 94108', 'New York NY 10012',
#        'Pittsburgh PA 15218', 'Santa Monica CA 90405',
#        'Warrenville IL 60555', 'Austin TX 78729',
#        'Marlborough MA 01752-4603', 'New York NY 10154',
#        'Playa Vista CA 90094', 'Providence RI 2906',
#        'Mountain View CA 94043-1107', 'Plano TX 75023',
#        'Chicago IL 60657', 'Austin TX 78701', 'Portland OR 97209',
#        'Allentown PA 18106', 'Los Angeles CA 90017', 'Denver CO 80202',
#        'Providence RI 2903', 'Redwood City CA 94065',
#        'Salt Lake City UT 84124', 'Palo Alto CA 94306',
#        'Burlington MA 1803', 'Seattle WA 98103', 'Alameda CA 94501',
#        'Durham NC 27701', 'Redwood City CA 94063', 'San Mateo CA 94401',
#        'Weston FL 33327', 'San Francisco CA 94104',
#        'Santa Monica CA 90401', 'Santa Clara CA 95054',
#        'Mountain View CA 94040', 'SPOKANE WA 99202', 'Maynard MA 1754',
#        'Frederick MD 21703', 'West Newfield ME 4095', 'NY NY 10011',
#        'San Francisco CA 94111', 'Austin TX 78759', 'San Diego CA 92130',
#        'Richardson TX 75081', 'Herndon VA 20170', 'Paramus NJ 7652',
#        'Minneapolis MN 55311', 'Durham NC 27713', 'New York NY 10005',
#        'Addison TX 75001', 'Irvine CA 92612', 'Woburn MA 1801',
#        'New York City NY 10013', 'Los Angeles CA 90046',
#        'San Bruno CA 94066', 'Boston MA 2114', 'Irvine CA 92618',
#        'Santa Monica CA 90404', 'New York NY 10016', 'Henderson NV 89052',
#        'Woodbury NY 11797', 'New York NY 10010', 'Littleton MA 1460',
#        'Los Angeles CA 90032', 'Los Gatos CA 95030',
#        'Broomfield CO 80021', 'Portland OR 97214', 'Boston MA 2111',
#        'Beverly Hills CA 90211', 'Hartford CT 6103',
#        'Greenwood Village CO 80111', 'Seattle WA 98109',
#        'College Park MD 20742', 'Los Angeles CA 90015',
#        'New York NY 10119', 'Lexington MA 2421', 'Foster City CA 94404',
#        'Los Angeles CA 90049', 'Richardson TX 75082',
#        'Los Angeles CA 90064', 'Albuquerque NM 87102', 'Red Bank NJ 7701',
#        'Boston MA 2110', 'New York City NY 10018', 'Brooklyn NY 11201',
#        'Philadelphia PA 19104', 'Los Angeles CA 90024',
#        'San Mateo CA 94403', 'New Hope PA 18938', 'Los Angeles CA 90039',
#        'Petaluma CA 94954', 'North Hollywood CA 91601',
#        'New York City NY 10010', 'West Chester PA 19380',
#        'Nashville TN 37201', 'Bedford MA 1730', 'Puyallup WA 98371',
#        'Boxborough MA 1719', 'San Mateo CA 94404', 'Louisville CO 80027',
#        'Campbell CA 95008-2069', 'New York NY 10017',
#        'Lexington KY 40507', 'Lake Oswego OR 97035', 'Dedham MA 2026',
#        'Lawrenceville GA 30043', 'Jersey City NJ 7302', 'NYC NY 10012',
#        'Annapolis MD 21401', 'Washington DC 20009', 'Las Vegas NV 89101',
#        'Minnetonka MN 55343', 'New York NY 10014', 'Vancouver WA 98665',
#        'Pleasanton CA 94566', 'El Segundo CA 90245', 'Farmington CT 6032',
#        'San Jose CA 95138', 'San Francisco CA 94133',
#        'Menlo Park CA 94025', 'Seattle WA 98121', 'Saint Paul MN 55113',
#        'Philadelphia PA 19103', 'Champaign IL 61820',
#        'Golden Valley MN 55416', 'Cambridge MA 2140', 'Seattle WA 98102',
#        'Brisbane CA 94005', 'Westford MA 1886', 'Raleigh NC 27518',
#        'Billerica MA 1821', 'Chicago IL 60654', 'Campbell CA 95008',
#        'Brooklyn NY 11217', 'Brooklyn NY 11222', 'San Jose CA 95110',
#        'Austin TX 78730', 'Washington DC 20005', 'Waltham MA 2452',
#        'Fremont CA 94555-3619', 'San Francisco CA 92606',
#        'Hollywood CA 90028', 'Los Angeles CA 90301',
#        'Hillsborough NJ 8844', 'Potomac Falls VA 20165',
#        'Santa Barbara CA 93105', 'Chicago CA 60606', 'Framingham MA 1702',
#        'Rye Brook NY 10573', 'Brooklyn NY 11211', 'Yardley PA 19067',
#        'San Francisco CA 94109', 'San Rafael CA 94903',
#        'Pasadena CA 91105', 'Portland OR 97201', 'Cambridge MA 2142',
#        'Sunnyvale CA 94089', 'Kenmore NY 14217', 'La Jolla CA 92037',
#        'Pleasanton CA 94588', 'San Diego CA 92130-2042',
#        'Cleveland OH 44131', 'Provo UT 84087', 'Palo Alto CA 94304',
#        'New York NY 10036', 'Columbus OH 43207', 'Portland OR 97204',
#        'Sunnyvale CA 94086', 'Redwood City CA 94063-2026',
#        'Yorba Linda CA 92887', 'Tempe AZ 85284', 'Toledo OH 43607',
#        'Seattle WA 98101', 'Carlsbad CA 92008', 'San Mateo CA 94402',
#        'Westport CT 6880', 'Chelmsford MA 1824', 'Boulder CO 80302',
#        'Austin TX 78746', 'Hampton NJ 8827', 'Idaho Falls ID 83402',
#        'Mountain View CA 94040-2573', 'Acton MA 1720',
#        'Aliso Viejo CA 92656', 'Portland OR 97224',
#        'Palo Alto CA 94301-1705', 'Little Rock AR 72201',
#        'Houston TX 77046'], dtype=object)

# %%
import re

# %%
# --- 1. Define the Regex Pattern ---
# Pattern: (City) + (StateCode) + (ZIPCode)
# The pattern uses (\d{4,5}) to handle both 5-digit and 4-digit ZIP codes.
LOCATION_PATTERN = re.compile(r'(.*?)\s+([A-Z]{2})\s+(\d{4,5})')

print("--- Location Comparison Check (No DataFrame Modified) ---")
print("Format: (Index) | Overall Status | Specific Component Matches | Extracted Data | Existing Data | Source Value")
print("-" * 140)

total_checks = 0
total_matches = 0

# Iterate through the DataFrame rows
for index, row in df.iterrows():
    location_str = row['Unnamed: 6']

    # Crucially, skip null/NaN values
    if pd.isna(location_str):
        print(f"({index:02d}) | --- SKIPPED --- (Source is NaN)")
        continue

    total_checks += 1
    location_str = str(location_str).strip()
    match = LOCATION_PATTERN.search(location_str)

    if match:
        # 1. Extract components and standardize (strip whitespace, lowercase)
        extracted_city = match.group(1).strip().lower()
        extracted_state_code = match.group(2).lower()
        extracted_zip_code = match.group(3)

        # 2. Get existing components and standardize (strip whitespace, lowercase)
        # Note: 'zip_code' is treated as a string for comparison
        existing_city = str(row['city']).strip().lower()
        existing_state_code = str(row['state_code']).strip().lower()
        existing_zip_code = str(row['zip_code']).strip()

        # 3. Perform comparisons (case/whitespace insensitive)
        zip_match = extracted_zip_code == existing_zip_code
        state_match = extracted_state_code == existing_state_code
        city_match = extracted_city == existing_city

        all_match = zip_match and state_match and city_match

        if all_match:
            total_matches += 1

        # 4. Format the output
        city_status = 'City' if city_match else 'CITY ❌'
        state_status = 'State' if state_match else 'STATE ❌'
        zip_status = 'ZIP' if zip_match else 'ZIP ❌'

        extracted_loc = f"{match.group(1)}, {match.group(2)} {match.group(3)}"
        existing_loc = f"{row['city']}, {row['state_code']} {row['zip_code']}"

        print(f"({index:02d}) | {'✅ MATCH' if all_match else '❌ MISMATCH'} ({city_status}, {state_status}, {zip_status}) | Extracted: '{extracted_loc}' | Existing: '{existing_loc}' | Source: '{location_str}'")

    else:
        print(f"({index:02d}) | ❓ NO REGEX MATCH | Source: '{location_str}'")

print("-" * 140)
print(f"Summary: {total_matches} out of {total_checks} non-null records fully matched.")
# Out:
# --- Location Comparison Check (No DataFrame Modified) ---
# Format: (Index) | Overall Status | Specific Component Matches | Extracted Data | Existing Data | Source Value
# --------------------------------------------------------------------------------------------------------------------------------------------
# (00) | --- SKIPPED --- (Source is NaN)
# (01) | --- SKIPPED --- (Source is NaN)
# (02) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Diego, CA 92121' | Existing: 'San Diego, CA 92121' | Source: 'San Diego CA 92121'
# (03) | ✅ MATCH (City, State, ZIP) | Extracted: 'Cupertino, CA 95014' | Existing: 'Cupertino, CA 95014' | Source: 'Cupertino CA 95014'
# (04) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94105' | Existing: 'San Francisco, CA 94105' | Source: 'San Francisco CA 94105'
# (05) | ✅ MATCH (City, State, ZIP) | Extracted: 'Mountain View, CA 94043' | Existing: 'Mountain View, CA 94043' | Source: 'Mountain View CA 94043'
# (06) | --- SKIPPED --- (Source is NaN)
# (07) | --- SKIPPED --- (Source is NaN)
# (08) | ✅ MATCH (City, State, ZIP) | Extracted: 'Williamstown, MA 1267' | Existing: 'Williamstown, MA 1267' | Source: 'Williamstown MA 1267'
# (09) | --- SKIPPED --- (Source is NaN)
# (10) | --- SKIPPED --- (Source is NaN)
# (11) | --- SKIPPED --- (Source is NaN)
# (12) | --- SKIPPED --- (Source is NaN)
# (13) | --- SKIPPED --- (Source is NaN)
# (14) | --- SKIPPED --- (Source is NaN)
# (15) | ✅ MATCH (City, State, ZIP) | Extracted: 'Vienna, VA 22182' | Existing: 'Vienna, VA 22182' | Source: 'Vienna VA 22182'
# (16) | --- SKIPPED --- (Source is NaN)
# (17) | --- SKIPPED --- (Source is NaN)
# (18) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10004' | Existing: 'New York, NY 10004' | Source: 'New York NY 10004'
# (19) | --- SKIPPED --- (Source is NaN)
# (20) | --- SKIPPED --- (Source is NaN)
# (21) | --- SKIPPED --- (Source is NaN)
# (22) | --- SKIPPED --- (Source is NaN)
# (23) | --- SKIPPED --- (Source is NaN)
# (24) | --- SKIPPED --- (Source is NaN)
# (25) | ✅ MATCH (City, State, ZIP) | Extracted: 'Chicago, IL 60601' | Existing: 'Chicago, IL 60601' | Source: 'Chicago IL 60601'
# (26) | --- SKIPPED --- (Source is NaN)
# (27) | ✅ MATCH (City, State, ZIP) | Extracted: 'Berkeley, CA 94704' | Existing: 'Berkeley, CA 94704' | Source: 'Berkeley CA 94704'
# (28) | --- SKIPPED --- (Source is NaN)
# (29) | ✅ MATCH (City, State, ZIP) | Extracted: 'Santa Ana, CA 92705' | Existing: 'Santa Ana, CA 92705' | Source: 'Santa Ana CA 92705'
# (30) | ✅ MATCH (City, State, ZIP) | Extracted: 'Moffett Field, CA 94035' | Existing: 'Moffett Field, CA 94035' | Source: 'Moffett Field CA 94035'
# (31) | ✅ MATCH (City, State, ZIP) | Extracted: 'Seattle, WA 98119' | Existing: 'Seattle, WA 98119' | Source: 'Seattle WA 98119'
# (32) | --- SKIPPED --- (Source is NaN)
# (33) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94105' | Existing: 'San Francisco, CA 94105' | Source: 'San Francisco CA 94105'
# (34) | ✅ MATCH (City, State, ZIP) | Extracted: 'Pittsburgh, PA 15219' | Existing: 'Pittsburgh, PA 15219' | Source: 'Pittsburgh PA 15219'
# (35) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10011' | Existing: 'New York, NY 10011' | Source: 'New York NY 10011'
# (36) | --- SKIPPED --- (Source is NaN)
# (37) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Jose, CA 95134' | Existing: 'San Jose, CA 95134' | Source: 'San Jose CA 95134'
# (38) | --- SKIPPED --- (Source is NaN)
# (39) | --- SKIPPED --- (Source is NaN)
# (40) | --- SKIPPED --- (Source is NaN)
# (41) | ✅ MATCH (City, State, ZIP) | Extracted: 'Manchester, NH 3101' | Existing: 'Manchester, NH 3101' | Source: 'Manchester NH 3101'
# (42) | --- SKIPPED --- (Source is NaN)
# (43) | --- SKIPPED --- (Source is NaN)
# (44) | --- SKIPPED --- (Source is NaN)
# (45) | ✅ MATCH (City, State, ZIP) | Extracted: 'Sunnyvale, CA 94085' | Existing: 'Sunnyvale, CA 94085' | Source: 'Sunnyvale CA 94085'
# (46) | ❌ MISMATCH (City, State, ZIP ❌) | Extracted: 'New York, NY 10001' | Existing: 'New York, NY 100011' | Source: 'New York NY 100011'
# (47) | ✅ MATCH (City, State, ZIP) | Extracted: 'Cambridge, MA 2139' | Existing: 'Cambridge, MA 2139' | Source: 'Cambridge MA 2139'
# (48) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94607' | Existing: 'San Francisco, CA 94607' | Source: 'San Francisco CA 94607'
# (49) | --- SKIPPED --- (Source is NaN)
# (50) | ✅ MATCH (City, State, ZIP) | Extracted: 'South San Francisco, CA 94080' | Existing: 'South San Francisco, CA 94080' | Source: 'South San Francisco CA 94080'
# (51) | ✅ MATCH (City, State, ZIP) | Extracted: 'Boston, MA 2210' | Existing: 'Boston, MA 2210' | Source: 'Boston MA 2210'
# (52) | ✅ MATCH (City, State, ZIP) | Extracted: 'Austin, TX 78731' | Existing: 'Austin, TX 78731' | Source: 'Austin TX 78731'
# (53) | ✅ MATCH (City, State, ZIP) | Extracted: 'Waltham, MA 2451' | Existing: 'Waltham, MA 2451' | Source: 'Waltham MA 2451'
# (54) | --- SKIPPED --- (Source is NaN)
# (55) | ✅ MATCH (City, State, ZIP) | Extracted: 'Palo Alto, CA 94301' | Existing: 'Palo Alto, CA 94301' | Source: 'Palo Alto CA 94301'
# (56) | ✅ MATCH (City, State, ZIP) | Extracted: 'Palo Alto, CA 95128' | Existing: 'Palo Alto, CA 95128' | Source: 'Palo Alto CA 95128'
# (57) | --- SKIPPED --- (Source is NaN)
# (58) | --- SKIPPED --- (Source is NaN)
# (59) | --- SKIPPED --- (Source is NaN)
# (60) | ✅ MATCH (City, State, ZIP) | Extracted: 'Wilmington, MA 1887' | Existing: 'Wilmington, MA 1887' | Source: 'Wilmington MA 1887'
# (61) | --- SKIPPED --- (Source is NaN)
# (62) | ❌ MISMATCH (City, State, ZIP ❌) | Extracted: 'Kirkland, WA 98033' | Existing: 'Kirkland, WA 98033-6314' | Source: 'Kirkland WA 98033-6314'
# (63) | ✅ MATCH (City, State, ZIP) | Extracted: 'Tampa, FL 33609' | Existing: 'Tampa, FL 33609' | Source: 'Tampa FL 33609'
# (64) | ❌ MISMATCH (City, State, ZIP ❌) | Extracted: 'Boston, MA 02111' | Existing: 'Boston, MA 02111-1720' | Source: 'Boston MA 02111-1720'
# (65) | --- SKIPPED --- (Source is NaN)
# (66) | --- SKIPPED --- (Source is NaN)
# (67) | --- SKIPPED --- (Source is NaN)
# (68) | --- SKIPPED --- (Source is NaN)
# (69) | --- SKIPPED --- (Source is NaN)
# (70) | --- SKIPPED --- (Source is NaN)
# (71) | --- SKIPPED --- (Source is NaN)
# (72) | --- SKIPPED --- (Source is NaN)
# (73) | --- SKIPPED --- (Source is NaN)
# (74) | --- SKIPPED --- (Source is NaN)
# (75) | ✅ MATCH (City, State, ZIP) | Extracted: 'Fremont, CA 94538' | Existing: 'Fremont, CA 94538' | Source: 'Fremont CA 94538'
# (76) | ✅ MATCH (City, State, ZIP) | Extracted: 'Santa Clara, CA 95051' | Existing: 'Santa Clara, CA 95051' | Source: 'Santa Clara CA 95051'
# (77) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94107' | Existing: 'San Francisco, CA 94107' | Source: 'San Francisco CA 94107'
# (78) | --- SKIPPED --- (Source is NaN)
# (79) | ✅ MATCH (City, State, ZIP) | Extracted: 'Cambridge, MA 2138' | Existing: 'Cambridge, MA 2138' | Source: 'Cambridge MA 2138'
# (80) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94105' | Existing: 'San Francisco, CA 94105' | Source: 'San Francisco CA 94105'
# (81) | ✅ MATCH (City, State, ZIP) | Extracted: 'Princeton, NJ 8540' | Existing: 'Princeton, NJ 8540' | Source: 'Princeton NJ 8540'
# (82) | ✅ MATCH (City, State, ZIP) | Extracted: 'Loveland, CO 80538' | Existing: 'Loveland, CO 80538' | Source: 'Loveland CO 80538'
# (83) | --- SKIPPED --- (Source is NaN)
# (84) | --- SKIPPED --- (Source is NaN)
# (85) | ✅ MATCH (City, State, ZIP) | Extracted: 'Kearneysville, WV 25430' | Existing: 'Kearneysville, WV 25430' | Source: 'Kearneysville WV 25430'
# (86) | --- SKIPPED --- (Source is NaN)
# (87) | --- SKIPPED --- (Source is NaN)
# (88) | ✅ MATCH (City, State, ZIP) | Extracted: 'Mountain View, CA 94041' | Existing: 'Mountain View, CA 94041' | Source: 'Mountain View CA 94041'
# (89) | --- SKIPPED --- (Source is NaN)
# (90) | --- SKIPPED --- (Source is NaN)
# (91) | --- SKIPPED --- (Source is NaN)
# (92) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94105' | Existing: 'San Francisco, CA 94105' | Source: 'San Francisco CA 94105'
# (93) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94110' | Existing: 'San Francisco, CA 94110' | Source: 'San Francisco CA 94110'
# (94) | --- SKIPPED --- (Source is NaN)
# (95) | ✅ MATCH (City, State, ZIP) | Extracted: 'Mountain View, CA 94043' | Existing: 'Mountain View, CA 94043' | Source: 'Mountain View CA 94043'
# (96) | --- SKIPPED --- (Source is NaN)
# (97) | --- SKIPPED --- (Source is NaN)
# (98) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94105' | Existing: 'San Francisco, CA 94105' | Source: 'San Francisco CA 94105'
# (99) | --- SKIPPED --- (Source is NaN)
# (100) | ✅ MATCH (City, State, ZIP) | Extracted: 'Alpharetta, GA 30009' | Existing: 'Alpharetta, GA 30009' | Source: 'Alpharetta GA 30009'
# (101) | ✅ MATCH (City, State, ZIP) | Extracted: 'Seattle, WA 98104' | Existing: 'Seattle, WA 98104' | Source: 'Seattle WA 98104'
# (102) | ✅ MATCH (City, State, ZIP) | Extracted: 'Bellevue, WA 98004' | Existing: 'Bellevue, WA 98004' | Source: 'Bellevue WA 98004'
# (103) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Jose, CA 95128' | Existing: 'San Jose, CA 95128' | Source: 'San Jose CA 95128'
# (104) | --- SKIPPED --- (Source is NaN)
# (105) | --- SKIPPED --- (Source is NaN)
# (106) | --- SKIPPED --- (Source is NaN)
# (107) | ✅ MATCH (City, State, ZIP) | Extracted: 'Chicago, IL 60607' | Existing: 'Chicago, IL 60607' | Source: 'Chicago IL 60607'
# (108) | --- SKIPPED --- (Source is NaN)
# (109) | --- SKIPPED --- (Source is NaN)
# (110) | --- SKIPPED --- (Source is NaN)
# (111) | --- SKIPPED --- (Source is NaN)
# (112) | ❌ MISMATCH (City, State, ZIP ❌) | Extracted: 'Milpitas, CA 95035' | Existing: 'Milpitas, CA 95035-6261' | Source: 'Milpitas CA 95035-6261'
# (113) | --- SKIPPED --- (Source is NaN)
# (114) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Diego, CA 92101' | Existing: 'San Diego, CA 92101' | Source: 'San Diego CA 92101'
# (115) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94103' | Existing: 'San Francisco, CA 94103' | Source: 'San Francisco CA 94103'
# (116) | ✅ MATCH (City, State, ZIP) | Extracted: 'Burlingame, CA 94010' | Existing: 'Burlingame, CA 94010' | Source: 'Burlingame CA 94010'
# (117) | --- SKIPPED --- (Source is NaN)
# (118) | --- SKIPPED --- (Source is NaN)
# (119) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10001' | Existing: 'New York, NY 10001' | Source: 'New York NY 10001'
# (120) | ✅ MATCH (City, State, ZIP) | Extracted: 'Somerville, MA 2143' | Existing: 'Somerville, MA 2143' | Source: 'Somerville MA 2143'
# (121) | --- SKIPPED --- (Source is NaN)
# (122) | --- SKIPPED --- (Source is NaN)
# (123) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10003' | Existing: 'New York, NY 10003' | Source: 'New York NY 10003'
# (124) | ✅ MATCH (City, State, ZIP) | Extracted: 'Fremont, CA 94538' | Existing: 'Fremont, CA 94538' | Source: 'Fremont CA 94538'
# (125) | ✅ MATCH (City, State, ZIP) | Extracted: 'Waltham, MA 2451' | Existing: 'Waltham, MA 2451' | Source: 'Waltham MA 2451'
# (126) | ✅ MATCH (City, State, ZIP) | Extracted: 'Timonium, MD 21093' | Existing: 'Timonium, MD 21093' | Source: 'Timonium MD 21093'
# (127) | ✅ MATCH (City, State, ZIP) | Extracted: 'Pittsburgh, PA 15213' | Existing: 'Pittsburgh, PA 15213' | Source: 'Pittsburgh PA 15213'
# (128) | ✅ MATCH (City, State, ZIP) | Extracted: 'Reston, VA 20191' | Existing: 'Reston, VA 20191' | Source: 'Reston VA 20191'
# (129) | --- SKIPPED --- (Source is NaN)
# (130) | --- SKIPPED --- (Source is NaN)
# (131) | ✅ MATCH (City, State, ZIP) | Extracted: 'Chicago, IL 60606' | Existing: 'Chicago, IL 60606' | Source: 'Chicago IL 60606'
# (132) | --- SKIPPED --- (Source is NaN)
# (133) | ✅ MATCH (City, State, ZIP) | Extracted: 'Palo Alto, CA 94303' | Existing: 'Palo Alto, CA 94303' | Source: 'Palo Alto CA 94303'
# (134) | ✅ MATCH (City, State, ZIP) | Extracted: 'Cincinnati, OH 45202' | Existing: 'Cincinnati, OH 45202' | Source: 'Cincinnati OH 45202'
# (135) | ✅ MATCH (City, State, ZIP) | Extracted: 'Atlanta, GA 30305' | Existing: 'Atlanta, GA 30305' | Source: 'Atlanta GA 30305'
# (136) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Jose, CA 95134' | Existing: 'San Jose, CA 95134' | Source: 'San Jose CA 95134'
# (137) | --- SKIPPED --- (Source is NaN)
# (138) | --- SKIPPED --- (Source is NaN)
# (139) | --- SKIPPED --- (Source is NaN)
# (140) | --- SKIPPED --- (Source is NaN)
# (141) | --- SKIPPED --- (Source is NaN)
# (142) | --- SKIPPED --- (Source is NaN)
# (143) | --- SKIPPED --- (Source is NaN)
# (144) | ✅ MATCH (City, State, ZIP) | Extracted: 'Sterling, VA 20166' | Existing: 'Sterling, VA 20166' | Source: 'Sterling VA 20166'
# (145) | --- SKIPPED --- (Source is NaN)
# (146) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94107' | Existing: 'San Francisco, CA 94107' | Source: 'San Francisco CA 94107'
# (147) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10011' | Existing: 'New York, NY 10011' | Source: 'New York NY 10011'
# (148) | --- SKIPPED --- (Source is NaN)
# (149) | --- SKIPPED --- (Source is NaN)
# (150) | --- SKIPPED --- (Source is NaN)
# (151) | --- SKIPPED --- (Source is NaN)
# (152) | ✅ MATCH (City, State, ZIP) | Extracted: 'Oakland, CA 94609' | Existing: 'Oakland, CA 94609' | Source: 'Oakland CA 94609'
# (153) | --- SKIPPED --- (Source is NaN)
# (154) | --- SKIPPED --- (Source is NaN)
# (155) | --- SKIPPED --- (Source is NaN)
# (156) | --- SKIPPED --- (Source is NaN)
# (157) | ✅ MATCH (City, State, ZIP) | Extracted: 'Boston, MA 2109' | Existing: 'Boston, MA 2109' | Source: 'Boston MA 2109'
# (158) | ✅ MATCH (City, State, ZIP) | Extracted: 'Sunnyvale, CA 94085' | Existing: 'Sunnyvale, CA 94085' | Source: 'Sunnyvale CA 94085'
# (159) | --- SKIPPED --- (Source is NaN)
# (160) | --- SKIPPED --- (Source is NaN)
# (161) | ✅ MATCH (City, State, ZIP) | Extracted: 'Centennial, CO 80112' | Existing: 'Centennial, CO 80112' | Source: 'Centennial CO 80112'
# (162) | ✅ MATCH (City, State, ZIP) | Extracted: 'Chicago, IL 60631' | Existing: 'Chicago, IL 60631' | Source: 'Chicago IL 60631'
# (163) | --- SKIPPED --- (Source is NaN)
# (164) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Jose, CA 95134' | Existing: 'San Jose, CA 95134' | Source: 'San Jose CA 95134'
# (165) | --- SKIPPED --- (Source is NaN)
# (166) | --- SKIPPED --- (Source is NaN)
# (167) | ❌ MISMATCH (City, State, ZIP ❌) | Extracted: 'Memphis, TN 38103' | Existing: 'Memphis, TN 38103-4717' | Source: 'Memphis TN 38103-4717'
# (168) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10013' | Existing: 'New York, NY 10013' | Source: 'New York NY 10013'
# (169) | --- SKIPPED --- (Source is NaN)
# (170) | --- SKIPPED --- (Source is NaN)
# (171) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10013' | Existing: 'New York, NY 10013' | Source: 'New York NY 10013'
# (172) | ✅ MATCH (City, State, ZIP) | Extracted: 'Cambridge, MA 2139' | Existing: 'Cambridge, MA 2139' | Source: 'Cambridge MA 2139'
# (173) | ✅ MATCH (City, State, ZIP) | Extracted: 'Plymouth, MN 55441' | Existing: 'Plymouth, MN 55441' | Source: 'Plymouth MN 55441'
# (174) | --- SKIPPED --- (Source is NaN)
# (175) | --- SKIPPED --- (Source is NaN)
# (176) | ✅ MATCH (City, State, ZIP) | Extracted: 'Seattle, WA 98104' | Existing: 'Seattle, WA 98104' | Source: 'Seattle WA 98104'
# (177) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94108' | Existing: 'San Francisco, CA 94108' | Source: 'San Francisco CA 94108'
# (178) | --- SKIPPED --- (Source is NaN)
# (179) | --- SKIPPED --- (Source is NaN)
# (180) | --- SKIPPED --- (Source is NaN)
# (181) | --- SKIPPED --- (Source is NaN)
# (182) | --- SKIPPED --- (Source is NaN)
# (183) | --- SKIPPED --- (Source is NaN)
# (184) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10012' | Existing: 'New York, NY 10012' | Source: 'New York NY 10012'
# (185) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94108' | Existing: 'San Francisco, CA 94108' | Source: 'San Francisco CA 94108'
# (186) | --- SKIPPED --- (Source is NaN)
# (187) | --- SKIPPED --- (Source is NaN)
# (188) | --- SKIPPED --- (Source is NaN)
# (189) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94103' | Existing: 'San Francisco, CA 94103' | Source: 'San Francisco CA 94103'
# (190) | ✅ MATCH (City, State, ZIP) | Extracted: 'Waltham, MA 2451' | Existing: 'Waltham, MA 2451' | Source: 'Waltham MA 2451'
# (191) | --- SKIPPED --- (Source is NaN)
# (192) | --- SKIPPED --- (Source is NaN)
# (193) | --- SKIPPED --- (Source is NaN)
# (194) | --- SKIPPED --- (Source is NaN)
# (195) | --- SKIPPED --- (Source is NaN)
# (196) | --- SKIPPED --- (Source is NaN)
# (197) | --- SKIPPED --- (Source is NaN)
# (198) | ✅ MATCH (City, State, ZIP) | Extracted: 'Pittsburgh, PA 15218' | Existing: 'Pittsburgh, PA 15218' | Source: 'Pittsburgh PA 15218'
# (199) | --- SKIPPED --- (Source is NaN)
# (200) | ✅ MATCH (City, State, ZIP) | Extracted: 'Santa Monica, CA 90405' | Existing: 'Santa Monica, CA 90405' | Source: 'Santa Monica CA 90405'
# (201) | ✅ MATCH (City, State, ZIP) | Extracted: 'Warrenville, IL 60555' | Existing: 'Warrenville, IL 60555' | Source: 'Warrenville IL 60555'
# (202) | --- SKIPPED --- (Source is NaN)
# (203) | --- SKIPPED --- (Source is NaN)
# (204) | --- SKIPPED --- (Source is NaN)
# (205) | --- SKIPPED --- (Source is NaN)
# (206) | --- SKIPPED --- (Source is NaN)
# (207) | --- SKIPPED --- (Source is NaN)
# (208) | --- SKIPPED --- (Source is NaN)
# (209) | ✅ MATCH (City, State, ZIP) | Extracted: 'Austin, TX 78729' | Existing: 'Austin, TX 78729' | Source: 'Austin TX 78729'
# (210) | ❌ MISMATCH (City, State, ZIP ❌) | Extracted: 'Marlborough, MA 01752' | Existing: 'Marlborough, MA 01752-4603' | Source: 'Marlborough MA 01752-4603'
# (211) | --- SKIPPED --- (Source is NaN)
# (212) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94110' | Existing: 'San Francisco, CA 94110' | Source: 'San Francisco CA 94110'
# (213) | --- SKIPPED --- (Source is NaN)
# (214) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10154' | Existing: 'New York, NY 10154' | Source: 'New York NY 10154'
# (215) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Jose, CA 95134' | Existing: 'San Jose, CA 95134' | Source: 'San Jose CA 95134'
# (216) | ✅ MATCH (City, State, ZIP) | Extracted: 'Playa Vista, CA 90094' | Existing: 'Playa Vista, CA 90094' | Source: 'Playa Vista CA 90094'
# (217) | --- SKIPPED --- (Source is NaN)
# (218) | ✅ MATCH (City, State, ZIP) | Extracted: 'Cupertino, CA 95014' | Existing: 'Cupertino, CA 95014' | Source: 'Cupertino CA 95014'
# (219) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10013' | Existing: 'New York, NY 10013' | Source: 'New York NY 10013'
# (220) | ✅ MATCH (City, State, ZIP) | Extracted: 'Providence, RI 2906' | Existing: 'Providence, RI 2906' | Source: 'Providence RI 2906'
# (221) | --- SKIPPED --- (Source is NaN)
# (222) | --- SKIPPED --- (Source is NaN)
# (223) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94105' | Existing: 'San Francisco, CA 94105' | Source: 'San Francisco CA 94105'
# (224) | --- SKIPPED --- (Source is NaN)
# (225) | --- SKIPPED --- (Source is NaN)
# (226) | ❌ MISMATCH (City, State, ZIP ❌) | Extracted: 'Mountain View, CA 94043' | Existing: 'Mountain View, CA 94043-1107' | Source: 'Mountain View CA 94043-1107'
# (227) | --- SKIPPED --- (Source is NaN)
# (228) | --- SKIPPED --- (Source is NaN)
# (229) | --- SKIPPED --- (Source is NaN)
# (230) | ✅ MATCH (City, State, ZIP) | Extracted: 'Plano, TX 75023' | Existing: 'Plano, TX 75023' | Source: 'Plano TX 75023'
# (231) | --- SKIPPED --- (Source is NaN)
# (232) | --- SKIPPED --- (Source is NaN)
# (233) | --- SKIPPED --- (Source is NaN)
# (234) | --- SKIPPED --- (Source is NaN)
# (235) | --- SKIPPED --- (Source is NaN)
# (236) | --- SKIPPED --- (Source is NaN)
# (237) | ✅ MATCH (City, State, ZIP) | Extracted: 'Chicago, IL 60657' | Existing: 'Chicago, IL 60657' | Source: 'Chicago IL 60657'
# (238) | --- SKIPPED --- (Source is NaN)
# (239) | --- SKIPPED --- (Source is NaN)
# (240) | ✅ MATCH (City, State, ZIP) | Extracted: 'Mountain View, CA 94043' | Existing: 'Mountain View, CA 94043' | Source: 'Mountain View CA 94043'
# (241) | --- SKIPPED --- (Source is NaN)
# (242) | --- SKIPPED --- (Source is NaN)
# (243) | --- SKIPPED --- (Source is NaN)
# (244) | --- SKIPPED --- (Source is NaN)
# (245) | ✅ MATCH (City, State, ZIP) | Extracted: 'Austin, TX 78701' | Existing: 'Austin, TX 78701' | Source: 'Austin TX 78701'
# (246) | --- SKIPPED --- (Source is NaN)
# (247) | --- SKIPPED --- (Source is NaN)
# (248) | ✅ MATCH (City, State, ZIP) | Extracted: 'Portland, OR 97209' | Existing: 'Portland, OR 97209' | Source: 'Portland OR 97209'
# (249) | --- SKIPPED --- (Source is NaN)
# (250) | ✅ MATCH (City, State, ZIP) | Extracted: 'Allentown, PA 18106' | Existing: 'Allentown, PA 18106' | Source: 'Allentown PA 18106'
# (251) | --- SKIPPED --- (Source is NaN)
# (252) | --- SKIPPED --- (Source is NaN)
# (253) | ✅ MATCH (City, State, ZIP) | Extracted: 'Los Angeles, CA 90017' | Existing: 'Los Angeles, CA 90017' | Source: 'Los Angeles CA 90017'
# (254) | ✅ MATCH (City, State, ZIP) | Extracted: 'Denver, CO 80202' | Existing: 'Denver, CO 80202' | Source: 'Denver CO 80202'
# (255) | --- SKIPPED --- (Source is NaN)
# (256) | ✅ MATCH (City, State, ZIP) | Extracted: 'Mountain View, CA 94043' | Existing: 'Mountain View, CA 94043' | Source: 'Mountain View CA 94043'
# (257) | ✅ MATCH (City, State, ZIP) | Extracted: 'Providence, RI 2903' | Existing: 'Providence, RI 2903' | Source: 'Providence RI 2903'
# (258) | --- SKIPPED --- (Source is NaN)
# (259) | --- SKIPPED --- (Source is NaN)
# (260) | --- SKIPPED --- (Source is NaN)
# (261) | --- SKIPPED --- (Source is NaN)
# (262) | ✅ MATCH (City, State, ZIP) | Extracted: 'Redwood City, CA 94065' | Existing: 'Redwood City, CA 94065' | Source: 'Redwood City CA 94065'
# (263) | ✅ MATCH (City, State, ZIP) | Extracted: 'Salt Lake City, UT 84124' | Existing: 'Salt Lake City, UT 84124' | Source: 'Salt Lake City UT 84124'
# (264) | --- SKIPPED --- (Source is NaN)
# (265) | ✅ MATCH (City, State, ZIP) | Extracted: 'Palo Alto, CA 94306' | Existing: 'Palo Alto, CA 94306' | Source: 'Palo Alto CA 94306'
# (266) | ✅ MATCH (City, State, ZIP) | Extracted: 'Austin, TX 78701' | Existing: 'Austin, TX 78701' | Source: 'Austin TX 78701'
# (267) | --- SKIPPED --- (Source is NaN)
# (268) | --- SKIPPED --- (Source is NaN)
# (269) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94105' | Existing: 'San Francisco, CA 94105' | Source: 'San Francisco CA 94105'
# (270) | ✅ MATCH (City, State, ZIP) | Extracted: 'Burlington, MA 1803' | Existing: 'Burlington, MA 1803' | Source: 'Burlington MA 1803'
# (271) | ✅ MATCH (City, State, ZIP) | Extracted: 'Seattle, WA 98103' | Existing: 'Seattle, WA 98103' | Source: 'Seattle WA 98103'
# (272) | --- SKIPPED --- (Source is NaN)
# (273) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94108' | Existing: 'San Francisco, CA 94108' | Source: 'San Francisco CA 94108'
# (274) | ✅ MATCH (City, State, ZIP) | Extracted: 'Alameda, CA 94501' | Existing: 'Alameda, CA 94501' | Source: 'Alameda CA 94501'
# (275) | ✅ MATCH (City, State, ZIP) | Extracted: 'Durham, NC 27701' | Existing: 'Durham, NC 27701' | Source: 'Durham NC 27701'
# (276) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10001' | Existing: 'New York, NY 10001' | Source: 'New York NY 10001'
# (277) | ✅ MATCH (City, State, ZIP) | Extracted: 'Redwood City, CA 94063' | Existing: 'Redwood City, CA 94063' | Source: 'Redwood City CA 94063'
# (278) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Mateo, CA 94401' | Existing: 'San Mateo, CA 94401' | Source: 'San Mateo CA 94401'
# (279) | --- SKIPPED --- (Source is NaN)
# (280) | ✅ MATCH (City, State, ZIP) | Extracted: 'Weston, FL 33327' | Existing: 'Weston, FL 33327' | Source: 'Weston FL 33327'
# (281) | --- SKIPPED --- (Source is NaN)
# (282) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94104' | Existing: 'San Francisco, CA 94104' | Source: 'San Francisco CA 94104'
# (283) | --- SKIPPED --- (Source is NaN)
# (284) | --- SKIPPED --- (Source is NaN)
# (285) | --- SKIPPED --- (Source is NaN)
# (286) | ✅ MATCH (City, State, ZIP) | Extracted: 'Santa Monica, CA 90401' | Existing: 'Santa Monica, CA 90401' | Source: 'Santa Monica CA 90401'
# (287) | --- SKIPPED --- (Source is NaN)
# (288) | ✅ MATCH (City, State, ZIP) | Extracted: 'Santa Clara, CA 95054' | Existing: 'Santa Clara, CA 95054' | Source: 'Santa Clara CA 95054'
# (289) | --- SKIPPED --- (Source is NaN)
# (290) | ✅ MATCH (City, State, ZIP) | Extracted: 'Mountain View, CA 94040' | Existing: 'Mountain View, CA 94040' | Source: 'Mountain View CA 94040'
# (291) | --- SKIPPED --- (Source is NaN)
# (292) | --- SKIPPED --- (Source is NaN)
# (293) | ✅ MATCH (City, State, ZIP) | Extracted: 'SPOKANE, WA 99202' | Existing: 'SPOKANE, WA 99202' | Source: 'SPOKANE WA 99202'
# (294) | --- SKIPPED --- (Source is NaN)
# (295) | ✅ MATCH (City, State, ZIP) | Extracted: 'Seattle, WA 98104' | Existing: 'Seattle, WA 98104' | Source: 'Seattle WA 98104'
# (296) | --- SKIPPED --- (Source is NaN)
# (297) | ✅ MATCH (City, State, ZIP) | Extracted: 'Maynard, MA 1754' | Existing: 'Maynard, MA 1754' | Source: 'Maynard MA 1754'
# (298) | ✅ MATCH (City, State, ZIP) | Extracted: 'Frederick, MD 21703' | Existing: 'Frederick, MD 21703' | Source: 'Frederick MD 21703'
# (299) | ✅ MATCH (City, State, ZIP) | Extracted: 'Fremont, CA 94538' | Existing: 'Fremont, CA 94538' | Source: 'Fremont CA 94538'
# (300) | ✅ MATCH (City, State, ZIP) | Extracted: 'Austin, TX 78701' | Existing: 'Austin, TX 78701' | Source: 'Austin TX 78701'
# (301) | --- SKIPPED --- (Source is NaN)
# (302) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10012' | Existing: 'New York, NY 10012' | Source: 'New York NY 10012'
# (303) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94105' | Existing: 'San Francisco, CA 94105' | Source: 'San Francisco CA 94105'
# (304) | ✅ MATCH (City, State, ZIP) | Extracted: 'Palo Alto, CA 94306' | Existing: 'Palo Alto, CA 94306' | Source: 'Palo Alto CA 94306'
# (305) | --- SKIPPED --- (Source is NaN)
# (306) | ✅ MATCH (City, State, ZIP) | Extracted: 'West Newfield, ME 4095' | Existing: 'West Newfield, ME 4095' | Source: 'West Newfield ME 4095'
# (307) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10011' | Existing: 'New York, NY 10011' | Source: 'New York NY 10011'
# (308) | --- SKIPPED --- (Source is NaN)
# (309) | --- SKIPPED --- (Source is NaN)
# (310) | --- SKIPPED --- (Source is NaN)
# (311) | --- SKIPPED --- (Source is NaN)
# (312) | --- SKIPPED --- (Source is NaN)
# (313) | --- SKIPPED --- (Source is NaN)
# (314) | ✅ MATCH (City, State, ZIP) | Extracted: 'Seattle, WA 98104' | Existing: 'Seattle, WA 98104' | Source: 'Seattle WA 98104'
# (315) | --- SKIPPED --- (Source is NaN)
# (316) | ✅ MATCH (City, State, ZIP) | Extracted: 'NY, NY 10011' | Existing: 'NY, NY 10011' | Source: 'NY NY 10011'
# (317) | --- SKIPPED --- (Source is NaN)
# (318) | --- SKIPPED --- (Source is NaN)
# (319) | --- SKIPPED --- (Source is NaN)
# (320) | --- SKIPPED --- (Source is NaN)
# (321) | --- SKIPPED --- (Source is NaN)
# (322) | --- SKIPPED --- (Source is NaN)
# (323) | --- SKIPPED --- (Source is NaN)
# (324) | --- SKIPPED --- (Source is NaN)
# (325) | --- SKIPPED --- (Source is NaN)
# (326) | --- SKIPPED --- (Source is NaN)
# (327) | --- SKIPPED --- (Source is NaN)
# (328) | --- SKIPPED --- (Source is NaN)
# (329) | --- SKIPPED --- (Source is NaN)
# (330) | --- SKIPPED --- (Source is NaN)
# (331) | --- SKIPPED --- (Source is NaN)
# (332) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94111' | Existing: 'San Francisco, CA 94111' | Source: 'San Francisco CA 94111'
# (333) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Diego, CA 92121' | Existing: 'San Diego, CA 92121' | Source: 'San Diego CA 92121'
# (334) | --- SKIPPED --- (Source is NaN)
# (335) | --- SKIPPED --- (Source is NaN)
# (336) | --- SKIPPED --- (Source is NaN)
# (337) | --- SKIPPED --- (Source is NaN)
# (338) | --- SKIPPED --- (Source is NaN)
# (339) | --- SKIPPED --- (Source is NaN)
# (340) | --- SKIPPED --- (Source is NaN)
# (341) | ✅ MATCH (City, State, ZIP) | Extracted: 'Burlington, MA 1803' | Existing: 'Burlington, MA 1803' | Source: 'Burlington MA 1803'
# (342) | ✅ MATCH (City, State, ZIP) | Extracted: 'Austin, TX 78759' | Existing: 'Austin, TX 78759' | Source: 'Austin TX 78759'
# (343) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Diego, CA 92130' | Existing: 'San Diego, CA 92130' | Source: 'San Diego CA 92130'
# (344) | --- SKIPPED --- (Source is NaN)
# (345) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10003' | Existing: 'New York, NY 10003' | Source: 'New York NY 10003'
# (346) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94108' | Existing: 'San Francisco, CA 94108' | Source: 'San Francisco CA 94108'
# (347) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10013' | Existing: 'New York, NY 10013' | Source: 'New York NY 10013'
# (348) | --- SKIPPED --- (Source is NaN)
# (349) | ✅ MATCH (City, State, ZIP) | Extracted: 'Richardson, TX 75081' | Existing: 'Richardson, TX 75081' | Source: 'Richardson TX 75081'
# (350) | --- SKIPPED --- (Source is NaN)
# (351) | ✅ MATCH (City, State, ZIP) | Extracted: 'Herndon, VA 20170' | Existing: 'Herndon, VA 20170' | Source: 'Herndon VA 20170'
# (352) | ✅ MATCH (City, State, ZIP) | Extracted: 'Paramus, NJ 7652' | Existing: 'Paramus, NJ 7652' | Source: 'Paramus NJ 7652'
# (353) | ✅ MATCH (City, State, ZIP) | Extracted: 'Pittsburgh, PA 15213' | Existing: 'Pittsburgh, PA 15213' | Source: 'Pittsburgh PA 15213'
# (354) | --- SKIPPED --- (Source is NaN)
# (355) | --- SKIPPED --- (Source is NaN)
# (356) | --- SKIPPED --- (Source is NaN)
# (357) | ✅ MATCH (City, State, ZIP) | Extracted: 'Minneapolis, MN 55311' | Existing: 'Minneapolis, MN 55311' | Source: 'Minneapolis MN 55311'
# (358) | --- SKIPPED --- (Source is NaN)
# (359) | --- SKIPPED --- (Source is NaN)
# (360) | ✅ MATCH (City, State, ZIP) | Extracted: 'Durham, NC 27713' | Existing: 'Durham, NC 27713' | Source: 'Durham NC 27713'
# (361) | --- SKIPPED --- (Source is NaN)
# (362) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10005' | Existing: 'New York, NY 10005' | Source: 'New York NY 10005'
# (363) | --- SKIPPED --- (Source is NaN)
# (364) | --- SKIPPED --- (Source is NaN)
# (365) | ✅ MATCH (City, State, ZIP) | Extracted: 'Addison, TX 75001' | Existing: 'Addison, TX 75001' | Source: 'Addison TX 75001'
# (366) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10001' | Existing: 'New York, NY 10001' | Source: 'New York NY 10001'
# (367) | ✅ MATCH (City, State, ZIP) | Extracted: 'Mountain View, CA 94043' | Existing: 'Mountain View, CA 94043' | Source: 'Mountain View CA 94043'
# (368) | ✅ MATCH (City, State, ZIP) | Extracted: 'Irvine, CA 92612' | Existing: 'Irvine, CA 92612' | Source: 'Irvine CA 92612'
# (369) | ✅ MATCH (City, State, ZIP) | Extracted: 'Woburn, MA 1801' | Existing: 'Woburn, MA 1801' | Source: 'Woburn MA 1801'
# (370) | --- SKIPPED --- (Source is NaN)
# (371) | ✅ MATCH (City, State, ZIP) | Extracted: 'Burlington, MA 1803' | Existing: 'Burlington, MA 1803' | Source: 'Burlington MA 1803'
# (372) | ✅ MATCH (City, State, ZIP) | Extracted: 'Boston, MA 2210' | Existing: 'Boston, MA 2210' | Source: 'Boston MA 2210'
# (373) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York City, NY 10013' | Existing: 'New York City, NY 10013' | Source: 'New York City NY 10013'
# (374) | --- SKIPPED --- (Source is NaN)
# (375) | ✅ MATCH (City, State, ZIP) | Extracted: 'Los Angeles, CA 90046' | Existing: 'Los Angeles, CA 90046' | Source: 'Los Angeles CA 90046'
# (376) | --- SKIPPED --- (Source is NaN)
# (377) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Bruno, CA 94066' | Existing: 'San Bruno, CA 94066' | Source: 'San Bruno CA 94066'
# (378) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94108' | Existing: 'San Francisco, CA 94108' | Source: 'San Francisco CA 94108'
# (379) | ✅ MATCH (City, State, ZIP) | Extracted: 'Boston, MA 2114' | Existing: 'Boston, MA 2114' | Source: 'Boston MA 2114'
# (380) | --- SKIPPED --- (Source is NaN)
# (381) | --- SKIPPED --- (Source is NaN)
# (382) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94103' | Existing: 'San Francisco, CA 94103' | Source: 'San Francisco CA 94103'
# (383) | ✅ MATCH (City, State, ZIP) | Extracted: 'Irvine, CA 92618' | Existing: 'Irvine, CA 92618' | Source: 'Irvine CA 92618'
# (384) | ✅ MATCH (City, State, ZIP) | Extracted: 'Santa Monica, CA 90404' | Existing: 'Santa Monica, CA 90404' | Source: 'Santa Monica CA 90404'
# (385) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10016' | Existing: 'New York, NY 10016' | Source: 'New York NY 10016'
# (386) | ✅ MATCH (City, State, ZIP) | Extracted: 'Palo Alto, CA 94306' | Existing: 'Palo Alto, CA 94306' | Source: 'Palo Alto CA 94306'
# (387) | ✅ MATCH (City, State, ZIP) | Extracted: 'Waltham, MA 2451' | Existing: 'Waltham, MA 2451' | Source: 'Waltham MA 2451'
# (388) | ✅ MATCH (City, State, ZIP) | Extracted: 'Santa Clara, CA 95051' | Existing: 'Santa Clara, CA 95051' | Source: 'Santa Clara CA 95051'
# (389) | ✅ MATCH (City, State, ZIP) | Extracted: 'Waltham, MA 2451' | Existing: 'Waltham, MA 2451' | Source: 'Waltham MA 2451'
# (390) | ✅ MATCH (City, State, ZIP) | Extracted: 'Henderson, NV 89052' | Existing: 'Henderson, NV 89052' | Source: 'Henderson NV 89052'
# (391) | --- SKIPPED --- (Source is NaN)
# (392) | --- SKIPPED --- (Source is NaN)
# (393) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Jose, CA 95134' | Existing: 'San Jose, CA 95134' | Source: 'San Jose CA 95134'
# (394) | ✅ MATCH (City, State, ZIP) | Extracted: 'Santa Clara, CA 95054' | Existing: 'Santa Clara, CA 95054' | Source: 'Santa Clara CA 95054'
# (395) | --- SKIPPED --- (Source is NaN)
# (396) | --- SKIPPED --- (Source is NaN)
# (397) | --- SKIPPED --- (Source is NaN)
# (398) | ✅ MATCH (City, State, ZIP) | Extracted: 'Mountain View, CA 94041' | Existing: 'Mountain View, CA 94041' | Source: 'Mountain View CA 94041'
# (399) | --- SKIPPED --- (Source is NaN)
# (400) | --- SKIPPED --- (Source is NaN)
# (401) | --- SKIPPED --- (Source is NaN)
# (402) | ✅ MATCH (City, State, ZIP) | Extracted: 'Bellevue, WA 98004' | Existing: 'Bellevue, WA 98004' | Source: 'Bellevue WA 98004'
# (403) | ✅ MATCH (City, State, ZIP) | Extracted: 'Woodbury, NY 11797' | Existing: 'Woodbury, NY 11797' | Source: 'Woodbury NY 11797'
# (404) | --- SKIPPED --- (Source is NaN)
# (405) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94103' | Existing: 'San Francisco, CA 94103' | Source: 'San Francisco CA 94103'
# (406) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10010' | Existing: 'New York, NY 10010' | Source: 'New York NY 10010'
# (407) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10003' | Existing: 'New York, NY 10003' | Source: 'New York NY 10003'
# (408) | --- SKIPPED --- (Source is NaN)
# (409) | ✅ MATCH (City, State, ZIP) | Extracted: 'Littleton, MA 1460' | Existing: 'Littleton, MA 1460' | Source: 'Littleton MA 1460'
# (410) | ✅ MATCH (City, State, ZIP) | Extracted: 'Los Angeles, CA 90032' | Existing: 'Los Angeles, CA 90032' | Source: 'Los Angeles CA 90032'
# (411) | --- SKIPPED --- (Source is NaN)
# (412) | --- SKIPPED --- (Source is NaN)
# (413) | --- SKIPPED --- (Source is NaN)
# (414) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10011' | Existing: 'New York, NY 10011' | Source: 'New York NY 10011'
# (415) | --- SKIPPED --- (Source is NaN)
# (416) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10001' | Existing: 'New York, NY 10001' | Source: 'New York NY 10001'
# (417) | --- SKIPPED --- (Source is NaN)
# (418) | --- SKIPPED --- (Source is NaN)
# (419) | --- SKIPPED --- (Source is NaN)
# (420) | --- SKIPPED --- (Source is NaN)
# (421) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10012' | Existing: 'New York, NY 10012' | Source: 'New York NY 10012'
# (422) | --- SKIPPED --- (Source is NaN)
# (423) | ✅ MATCH (City, State, ZIP) | Extracted: 'Los Gatos, CA 95030' | Existing: 'Los Gatos, CA 95030' | Source: 'Los Gatos CA 95030'
# (424) | ✅ MATCH (City, State, ZIP) | Extracted: 'Broomfield, CO 80021' | Existing: 'Broomfield, CO 80021' | Source: 'Broomfield CO 80021'
# (425) | --- SKIPPED --- (Source is NaN)
# (426) | ✅ MATCH (City, State, ZIP) | Extracted: 'Mountain View, CA 94040' | Existing: 'Mountain View, CA 94040' | Source: 'Mountain View CA 94040'
# (427) | ✅ MATCH (City, State, ZIP) | Extracted: 'Portland, OR 97214' | Existing: 'Portland, OR 97214' | Source: 'Portland OR 97214'
# (428) | --- SKIPPED --- (Source is NaN)
# (429) | ✅ MATCH (City, State, ZIP) | Extracted: 'Boston, MA 2111' | Existing: 'Boston, MA 2111' | Source: 'Boston MA 2111'
# (430) | ✅ MATCH (City, State, ZIP) | Extracted: 'Austin, TX 78701' | Existing: 'Austin, TX 78701' | Source: 'Austin TX 78701'
# (431) | ✅ MATCH (City, State, ZIP) | Extracted: 'Beverly Hills, CA 90211' | Existing: 'Beverly Hills, CA 90211' | Source: 'Beverly Hills CA 90211'
# (432) | ✅ MATCH (City, State, ZIP) | Extracted: 'Hartford, CT 6103' | Existing: 'Hartford, CT 6103' | Source: 'Hartford CT 6103'
# (433) | ✅ MATCH (City, State, ZIP) | Extracted: 'Greenwood Village, CO 80111' | Existing: 'Greenwood Village, CO 80111' | Source: 'Greenwood Village CO 80111'
# (434) | ✅ MATCH (City, State, ZIP) | Extracted: 'Seattle, WA 98109' | Existing: 'Seattle, WA 98109' | Source: 'Seattle WA 98109'
# (435) | ✅ MATCH (City, State, ZIP) | Extracted: 'College Park, MD 20742' | Existing: 'College Park, MD 20742' | Source: 'College Park MD 20742'
# (436) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10003' | Existing: 'New York, NY 10003' | Source: 'New York NY 10003'
# (437) | ✅ MATCH (City, State, ZIP) | Extracted: 'Los Angeles, CA 90015' | Existing: 'Los Angeles, CA 90015' | Source: 'Los Angeles CA 90015'
# (438) | --- SKIPPED --- (Source is NaN)
# (439) | --- SKIPPED --- (Source is NaN)
# (440) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94103' | Existing: 'San Francisco, CA 94103' | Source: 'San Francisco CA 94103'
# (441) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10119' | Existing: 'New York, NY 10119' | Source: 'New York NY 10119'
# (442) | --- SKIPPED --- (Source is NaN)
# (443) | --- SKIPPED --- (Source is NaN)
# (444) | --- SKIPPED --- (Source is NaN)
# (445) | --- SKIPPED --- (Source is NaN)
# (446) | ✅ MATCH (City, State, ZIP) | Extracted: 'Lexington, MA 2421' | Existing: 'Lexington, MA 2421' | Source: 'Lexington MA 2421'
# (447) | --- SKIPPED --- (Source is NaN)
# (448) | --- SKIPPED --- (Source is NaN)
# (449) | ✅ MATCH (City, State, ZIP) | Extracted: 'Irvine, CA 92618' | Existing: 'Irvine, CA 92618' | Source: 'Irvine CA 92618'
# (450) | ✅ MATCH (City, State, ZIP) | Extracted: 'Palo Alto, CA 94301' | Existing: 'Palo Alto, CA 94301' | Source: 'Palo Alto CA 94301'
# (451) | --- SKIPPED --- (Source is NaN)
# (452) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10013' | Existing: 'New York, NY 10013' | Source: 'New York NY 10013'
# (453) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94110' | Existing: 'San Francisco, CA 94110' | Source: 'San Francisco CA 94110'
# (454) | ✅ MATCH (City, State, ZIP) | Extracted: 'Foster City, CA 94404' | Existing: 'Foster City, CA 94404' | Source: 'Foster City CA 94404'
# (455) | --- SKIPPED --- (Source is NaN)
# (456) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10004' | Existing: 'New York, NY 10004' | Source: 'New York NY 10004'
# (457) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10011' | Existing: 'New York, NY 10011' | Source: 'New York NY 10011'
# (458) | --- SKIPPED --- (Source is NaN)
# (459) | --- SKIPPED --- (Source is NaN)
# (460) | --- SKIPPED --- (Source is NaN)
# (461) | ✅ MATCH (City, State, ZIP) | Extracted: 'Redwood City, CA 94063' | Existing: 'Redwood City, CA 94063' | Source: 'Redwood City CA 94063'
# (462) | --- SKIPPED --- (Source is NaN)
# (463) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94111' | Existing: 'San Francisco, CA 94111' | Source: 'San Francisco CA 94111'
# (464) | ✅ MATCH (City, State, ZIP) | Extracted: 'Austin, TX 78759' | Existing: 'Austin, TX 78759' | Source: 'Austin TX 78759'
# (465) | --- SKIPPED --- (Source is NaN)
# (466) | --- SKIPPED --- (Source is NaN)
# (467) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10001' | Existing: 'New York, NY 10001' | Source: 'New York NY 10001'
# (468) | ✅ MATCH (City, State, ZIP) | Extracted: 'Cincinnati, OH 45202' | Existing: 'Cincinnati, OH 45202' | Source: 'Cincinnati OH 45202'
# (469) | --- SKIPPED --- (Source is NaN)
# (470) | --- SKIPPED --- (Source is NaN)
# (471) | ✅ MATCH (City, State, ZIP) | Extracted: 'Cincinnati, OH 45202' | Existing: 'Cincinnati, OH 45202' | Source: 'Cincinnati OH 45202'
# (472) | ✅ MATCH (City, State, ZIP) | Extracted: 'Los Angeles, CA 90049' | Existing: 'Los Angeles, CA 90049' | Source: 'Los Angeles CA 90049'
# (473) | --- SKIPPED --- (Source is NaN)
# (474) | --- SKIPPED --- (Source is NaN)
# (475) | --- SKIPPED --- (Source is NaN)
# (476) | ✅ MATCH (City, State, ZIP) | Extracted: 'Richardson, TX 75082' | Existing: 'Richardson, TX 75082' | Source: 'Richardson TX 75082'
# (477) | --- SKIPPED --- (Source is NaN)
# (478) | ✅ MATCH (City, State, ZIP) | Extracted: 'Los Angeles, CA 90064' | Existing: 'Los Angeles, CA 90064' | Source: 'Los Angeles CA 90064'
# (479) | ✅ MATCH (City, State, ZIP) | Extracted: 'Albuquerque, NM 87102' | Existing: 'Albuquerque, NM 87102' | Source: 'Albuquerque NM 87102'
# (480) | ✅ MATCH (City, State, ZIP) | Extracted: 'Red Bank, NJ 7701' | Existing: 'Red Bank, NJ 7701' | Source: 'Red Bank NJ 7701'
# (481) | --- SKIPPED --- (Source is NaN)
# (482) | ✅ MATCH (City, State, ZIP) | Extracted: 'Boston, MA 2110' | Existing: 'Boston, MA 2110' | Source: 'Boston MA 2110'
# (483) | --- SKIPPED --- (Source is NaN)
# (484) | --- SKIPPED --- (Source is NaN)
# (485) | --- SKIPPED --- (Source is NaN)
# (486) | ✅ MATCH (City, State, ZIP) | Extracted: 'Santa Clara, CA 95051' | Existing: 'Santa Clara, CA 95051' | Source: 'Santa Clara CA 95051'
# (487) | --- SKIPPED --- (Source is NaN)
# (488) | --- SKIPPED --- (Source is NaN)
# (489) | --- SKIPPED --- (Source is NaN)
# (490) | --- SKIPPED --- (Source is NaN)
# (491) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York City, NY 10018' | Existing: 'New York City, NY 10018' | Source: 'New York City NY 10018'
# (492) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10016' | Existing: 'New York, NY 10016' | Source: 'New York NY 10016'
# (493) | --- SKIPPED --- (Source is NaN)
# (494) | ✅ MATCH (City, State, ZIP) | Extracted: 'Brooklyn, NY 11201' | Existing: 'Brooklyn, NY 11201' | Source: 'Brooklyn NY 11201'
# (495) | ✅ MATCH (City, State, ZIP) | Extracted: 'Philadelphia, PA 19104' | Existing: 'Philadelphia, PA 19104' | Source: 'Philadelphia PA 19104'
# (496) | ✅ MATCH (City, State, ZIP) | Extracted: 'Los Angeles, CA 90024' | Existing: 'Los Angeles, CA 90024' | Source: 'Los Angeles CA 90024'
# (497) | --- SKIPPED --- (Source is NaN)
# (498) | ✅ MATCH (City, State, ZIP) | Extracted: 'Burlington, MA 1803' | Existing: 'Burlington, MA 1803' | Source: 'Burlington MA 1803'
# (499) | --- SKIPPED --- (Source is NaN)
# (500) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Mateo, CA 94403' | Existing: 'San Mateo, CA 94403' | Source: 'San Mateo CA 94403'
# (501) | --- SKIPPED --- (Source is NaN)
# (502) | ✅ MATCH (City, State, ZIP) | Extracted: 'New Hope, PA 18938' | Existing: 'New Hope, PA 18938' | Source: 'New Hope PA 18938'
# (503) | --- SKIPPED --- (Source is NaN)
# (504) | ✅ MATCH (City, State, ZIP) | Extracted: 'Los Angeles, CA 90039' | Existing: 'Los Angeles, CA 90039' | Source: 'Los Angeles CA 90039'
# (505) | --- SKIPPED --- (Source is NaN)
# (506) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10003' | Existing: 'New York, NY 10003' | Source: 'New York NY 10003'
# (507) | ✅ MATCH (City, State, ZIP) | Extracted: 'Petaluma, CA 94954' | Existing: 'Petaluma, CA 94954' | Source: 'Petaluma CA 94954'
# (508) | --- SKIPPED --- (Source is NaN)
# (509) | ✅ MATCH (City, State, ZIP) | Extracted: 'North Hollywood, CA 91601' | Existing: 'North Hollywood, CA 91601' | Source: 'North Hollywood CA 91601'
# (510) | --- SKIPPED --- (Source is NaN)
# (511) | ✅ MATCH (City, State, ZIP) | Extracted: 'Santa Clara, CA 95054' | Existing: 'Santa Clara, CA 95054' | Source: 'Santa Clara CA 95054'
# (512) | --- SKIPPED --- (Source is NaN)
# (513) | --- SKIPPED --- (Source is NaN)
# (514) | --- SKIPPED --- (Source is NaN)
# (515) | --- SKIPPED --- (Source is NaN)
# (516) | --- SKIPPED --- (Source is NaN)
# (517) | --- SKIPPED --- (Source is NaN)
# (518) | --- SKIPPED --- (Source is NaN)
# (519) | --- SKIPPED --- (Source is NaN)
# (520) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York City, NY 10010' | Existing: 'New York City, NY 10010' | Source: 'New York City NY 10010'
# (521) | ✅ MATCH (City, State, ZIP) | Extracted: 'Mountain View, CA 94040' | Existing: 'Mountain View, CA 94040' | Source: 'Mountain View CA 94040'
# (522) | ✅ MATCH (City, State, ZIP) | Extracted: 'West Chester, PA 19380' | Existing: 'West Chester, PA 19380' | Source: 'West Chester PA 19380'
# (523) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94105' | Existing: 'San Francisco, CA 94105' | Source: 'San Francisco CA 94105'
# (524) | ✅ MATCH (City, State, ZIP) | Extracted: 'Nashville, TN 37201' | Existing: 'Nashville, TN 37201' | Source: 'Nashville TN 37201'
# (525) | --- SKIPPED --- (Source is NaN)
# (526) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10012' | Existing: 'New York, NY 10012' | Source: 'New York NY 10012'
# (527) | ✅ MATCH (City, State, ZIP) | Extracted: 'Bedford, MA 1730' | Existing: 'Bedford, MA 1730' | Source: 'Bedford MA 1730'
# (528) | --- SKIPPED --- (Source is NaN)
# (529) | --- SKIPPED --- (Source is NaN)
# (530) | --- SKIPPED --- (Source is NaN)
# (531) | ✅ MATCH (City, State, ZIP) | Extracted: 'Puyallup, WA 98371' | Existing: 'Puyallup, WA 98371' | Source: 'Puyallup WA 98371'
# (532) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Mateo, CA 94403' | Existing: 'San Mateo, CA 94403' | Source: 'San Mateo CA 94403'
# (533) | --- SKIPPED --- (Source is NaN)
# (534) | ✅ MATCH (City, State, ZIP) | Extracted: 'Boxborough, MA 1719' | Existing: 'Boxborough, MA 1719' | Source: 'Boxborough MA 1719'
# (535) | --- SKIPPED --- (Source is NaN)
# (536) | --- SKIPPED --- (Source is NaN)
# (537) | --- SKIPPED --- (Source is NaN)
# (538) | --- SKIPPED --- (Source is NaN)
# (539) | --- SKIPPED --- (Source is NaN)
# (540) | --- SKIPPED --- (Source is NaN)
# (541) | --- SKIPPED --- (Source is NaN)
# (542) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Mateo, CA 94404' | Existing: 'San Mateo, CA 94404' | Source: 'San Mateo CA 94404'
# (543) | --- SKIPPED --- (Source is NaN)
# (544) | --- SKIPPED --- (Source is NaN)
# (545) | --- SKIPPED --- (Source is NaN)
# (546) | --- SKIPPED --- (Source is NaN)
# (547) | --- SKIPPED --- (Source is NaN)
# (548) | ✅ MATCH (City, State, ZIP) | Extracted: 'Louisville, CO 80027' | Existing: 'Louisville, CO 80027' | Source: 'Louisville CO 80027'
# (549) | ✅ MATCH (City, State, ZIP) | Extracted: 'Woburn, MA 1801' | Existing: 'Woburn, MA 1801' | Source: 'Woburn MA 1801'
# (550) | --- SKIPPED --- (Source is NaN)
# (551) | --- SKIPPED --- (Source is NaN)
# (552) | ❌ MISMATCH (City, State, ZIP ❌) | Extracted: 'Campbell, CA 95008' | Existing: 'Campbell, CA 95008-2069' | Source: 'Campbell CA 95008-2069'
# (553) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10017' | Existing: 'New York, NY 10017' | Source: 'New York NY 10017'
# (554) | ✅ MATCH (City, State, ZIP) | Extracted: 'Palo Alto, CA 94301' | Existing: 'Palo Alto, CA 94301' | Source: 'Palo Alto CA 94301'
# (555) | --- SKIPPED --- (Source is NaN)
# (556) | ✅ MATCH (City, State, ZIP) | Extracted: 'Boxborough, MA 1719' | Existing: 'Boxborough, MA 1719' | Source: 'Boxborough MA 1719'
# (557) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94107' | Existing: 'San Francisco, CA 94107' | Source: 'San Francisco CA 94107'
# (558) | --- SKIPPED --- (Source is NaN)
# (559) | --- SKIPPED --- (Source is NaN)
# (560) | --- SKIPPED --- (Source is NaN)
# (561) | --- SKIPPED --- (Source is NaN)
# (562) | --- SKIPPED --- (Source is NaN)
# (563) | --- SKIPPED --- (Source is NaN)
# (564) | ✅ MATCH (City, State, ZIP) | Extracted: 'Mountain View, CA 94043' | Existing: 'Mountain View, CA 94043' | Source: 'Mountain View CA 94043'
# (565) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10001' | Existing: 'New York, NY 10001' | Source: 'New York NY 10001'
# (566) | ✅ MATCH (City, State, ZIP) | Extracted: 'Lexington, KY 40507' | Existing: 'Lexington, KY 40507' | Source: 'Lexington KY 40507'
# (567) | --- SKIPPED --- (Source is NaN)
# (568) | --- SKIPPED --- (Source is NaN)
# ...
# (737) | ✅ MATCH (City, State, ZIP) | Extracted: 'Mountain View, CA 94041' | Existing: 'Mountain View, CA 94041' | Source: 'Mountain View CA 94041'
# (738) | --- SKIPPED --- (Source is NaN)
# (739) | ✅ MATCH (City, State, ZIP) | Extracted: 'Santa Monica, CA 90401' | Existing: 'Santa Monica, CA 90401' | Source: 'Santa Monica CA 90401'
# (740) | --- SKIPPED --- (Source is NaN)
# (741) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94109' | Existing: 'San Francisco, CA 94109' | Source: 'San Francisco CA 94109'
# (742) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Rafael, CA 94903' | Existing: 'San Rafael, CA 94903' | Source: 'San Rafael CA 94903'
# (743) | ✅ MATCH (City, State, ZIP) | Extracted: 'Hollywood, CA 90028' | Existing: 'Hollywood, CA 90028' | Source: 'Hollywood CA 90028'
# (744) | --- SKIPPED --- (Source is NaN)
# (745) | ✅ MATCH (City, State, ZIP) | Extracted: 'Pasadena, CA 91105' | Existing: 'Pasadena, CA 91105' | Source: 'Pasadena CA 91105'
# (746) | --- SKIPPED --- (Source is NaN)
# (747) | --- SKIPPED --- (Source is NaN)
# (748) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10012' | Existing: 'New York, NY 10012' | Source: 'New York NY 10012'
# (749) | --- SKIPPED --- (Source is NaN)
# (750) | ✅ MATCH (City, State, ZIP) | Extracted: 'Portland, OR 97201' | Existing: 'Portland, OR 97201' | Source: 'Portland OR 97201'
# (751) | --- SKIPPED --- (Source is NaN)
# (752) | ✅ MATCH (City, State, ZIP) | Extracted: 'Cambridge, MA 2142' | Existing: 'Cambridge, MA 2142' | Source: 'Cambridge MA 2142'
# (753) | ✅ MATCH (City, State, ZIP) | Extracted: 'Sunnyvale, CA 94089' | Existing: 'Sunnyvale, CA 94089' | Source: 'Sunnyvale CA 94089'
# (754) | ✅ MATCH (City, State, ZIP) | Extracted: 'Kenmore, NY 14217' | Existing: 'Kenmore, NY 14217' | Source: 'Kenmore NY 14217'
# (755) | --- SKIPPED --- (Source is NaN)
# (756) | --- SKIPPED --- (Source is NaN)
# (757) | --- SKIPPED --- (Source is NaN)
# (758) | ✅ MATCH (City, State, ZIP) | Extracted: 'La Jolla, CA 92037' | Existing: 'La Jolla, CA 92037' | Source: 'La Jolla CA 92037'
# (759) | --- SKIPPED --- (Source is NaN)
# (760) | --- SKIPPED --- (Source is NaN)
# (761) | --- SKIPPED --- (Source is NaN)
# (762) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94103' | Existing: 'San Francisco, CA 94103' | Source: 'San Francisco CA 94103'
# (763) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94110' | Existing: 'San Francisco, CA 94110' | Source: 'San Francisco CA 94110'
# (764) | --- SKIPPED --- (Source is NaN)
# (765) | ✅ MATCH (City, State, ZIP) | Extracted: 'Mountain View, CA 94041' | Existing: 'Mountain View, CA 94041' | Source: 'Mountain View CA 94041'
# (766) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10005' | Existing: 'New York, NY 10005' | Source: 'New York NY 10005'
# (767) | ✅ MATCH (City, State, ZIP) | Extracted: 'Pleasanton, CA 94588' | Existing: 'Pleasanton, CA 94588' | Source: 'Pleasanton CA 94588'
# (768) | ❌ MISMATCH (City, State, ZIP ❌) | Extracted: 'San Diego, CA 92130' | Existing: 'San Diego, CA 92130-2042' | Source: 'San Diego CA 92130-2042'
# (769) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10005' | Existing: 'New York, NY 10005' | Source: 'New York NY 10005'
# (770) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10003' | Existing: 'New York, NY 10003' | Source: 'New York NY 10003'
# (771) | ✅ MATCH (City, State, ZIP) | Extracted: 'Cleveland, OH 44131' | Existing: 'Cleveland, OH 44131' | Source: 'Cleveland OH 44131'
# (772) | --- SKIPPED --- (Source is NaN)
# (773) | ✅ MATCH (City, State, ZIP) | Extracted: 'Cambridge, MA 2142' | Existing: 'Cambridge, MA 2142' | Source: 'Cambridge MA 2142'
# (774) | --- SKIPPED --- (Source is NaN)
# (775) | --- SKIPPED --- (Source is NaN)
# (776) | --- SKIPPED --- (Source is NaN)
# (777) | --- SKIPPED --- (Source is NaN)
# (778) | --- SKIPPED --- (Source is NaN)
# (779) | ✅ MATCH (City, State, ZIP) | Extracted: 'Seattle, WA 98104' | Existing: 'Seattle, WA 98104' | Source: 'Seattle WA 98104'
# (780) | --- SKIPPED --- (Source is NaN)
# (781) | --- SKIPPED --- (Source is NaN)
# (782) | ✅ MATCH (City, State, ZIP) | Extracted: 'Provo, UT 84087' | Existing: 'Provo, UT 84087' | Source: 'Provo UT 84087'
# (783) | ✅ MATCH (City, State, ZIP) | Extracted: 'Palo Alto, CA 94304' | Existing: 'Palo Alto, CA 94304' | Source: 'Palo Alto CA 94304'
# (784) | --- SKIPPED --- (Source is NaN)
# (785) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10036' | Existing: 'New York, NY 10036' | Source: 'New York NY 10036'
# (786) | --- SKIPPED --- (Source is NaN)
# (787) | ✅ MATCH (City, State, ZIP) | Extracted: 'Columbus, OH 43207' | Existing: 'Columbus, OH 43207' | Source: 'Columbus OH 43207'
# (788) | --- SKIPPED --- (Source is NaN)
# (789) | ✅ MATCH (City, State, ZIP) | Extracted: 'Portland, OR 97204' | Existing: 'Portland, OR 97204' | Source: 'Portland OR 97204'
# (790) | --- SKIPPED --- (Source is NaN)
# (791) | --- SKIPPED --- (Source is NaN)
# (792) | --- SKIPPED --- (Source is NaN)
# (793) | --- SKIPPED --- (Source is NaN)
# (794) | --- SKIPPED --- (Source is NaN)
# (795) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10014' | Existing: 'New York, NY 10014' | Source: 'New York NY 10014'
# (796) | --- SKIPPED --- (Source is NaN)
# (797) | ✅ MATCH (City, State, ZIP) | Extracted: 'Cupertino, CA 95014' | Existing: 'Cupertino, CA 95014' | Source: 'Cupertino CA 95014'
# (798) | ✅ MATCH (City, State, ZIP) | Extracted: 'Sunnyvale, CA 94086' | Existing: 'Sunnyvale, CA 94086' | Source: 'Sunnyvale CA 94086'
# (799) | ✅ MATCH (City, State, ZIP) | Extracted: 'Mountain View, CA 94041' | Existing: 'Mountain View, CA 94041' | Source: 'Mountain View CA 94041'
# (800) | --- SKIPPED --- (Source is NaN)
# (801) | --- SKIPPED --- (Source is NaN)
# (802) | --- SKIPPED --- (Source is NaN)
# (803) | ❌ MISMATCH (City, State, ZIP ❌) | Extracted: 'Redwood City, CA 94063' | Existing: 'Redwood City, CA 94063-2026' | Source: 'Redwood City CA 94063-2026'
# (804) | --- SKIPPED --- (Source is NaN)
# (805) | --- SKIPPED --- (Source is NaN)
# (806) | ✅ MATCH (City, State, ZIP) | Extracted: 'Sunnyvale, CA 94085' | Existing: 'Sunnyvale, CA 94085' | Source: 'Sunnyvale CA 94085'
# (807) | --- SKIPPED --- (Source is NaN)
# (808) | ✅ MATCH (City, State, ZIP) | Extracted: 'Yorba Linda, CA 92887' | Existing: 'Yorba Linda, CA 92887' | Source: 'Yorba Linda CA 92887'
# (809) | --- SKIPPED --- (Source is NaN)
# (810) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10011' | Existing: 'New York, NY 10011' | Source: 'New York NY 10011'
# (811) | --- SKIPPED --- (Source is NaN)
# (812) | ✅ MATCH (City, State, ZIP) | Extracted: 'Palo Alto, CA 94301' | Existing: 'Palo Alto, CA 94301' | Source: 'Palo Alto CA 94301'
# (813) | --- SKIPPED --- (Source is NaN)
# (814) | ✅ MATCH (City, State, ZIP) | Extracted: 'Los Angeles, CA 90024' | Existing: 'Los Angeles, CA 90024' | Source: 'Los Angeles CA 90024'
# (815) | ✅ MATCH (City, State, ZIP) | Extracted: 'Palo Alto, CA 94301' | Existing: 'Palo Alto, CA 94301' | Source: 'Palo Alto CA 94301'
# (816) | --- SKIPPED --- (Source is NaN)
# (817) | --- SKIPPED --- (Source is NaN)
# (818) | ✅ MATCH (City, State, ZIP) | Extracted: 'Seattle, WA 98104' | Existing: 'Seattle, WA 98104' | Source: 'Seattle WA 98104'
# (819) | --- SKIPPED --- (Source is NaN)
# (820) | --- SKIPPED --- (Source is NaN)
# (821) | --- SKIPPED --- (Source is NaN)
# (822) | --- SKIPPED --- (Source is NaN)
# (823) | --- SKIPPED --- (Source is NaN)
# (824) | ✅ MATCH (City, State, ZIP) | Extracted: 'Tempe, AZ 85284' | Existing: 'Tempe, AZ 85284' | Source: 'Tempe AZ 85284'
# (825) | ✅ MATCH (City, State, ZIP) | Extracted: 'Sunnyvale, CA 94085' | Existing: 'Sunnyvale, CA 94085' | Source: 'Sunnyvale CA 94085'
# (826) | --- SKIPPED --- (Source is NaN)
# (827) | ✅ MATCH (City, State, ZIP) | Extracted: 'Toledo, OH 43607' | Existing: 'Toledo, OH 43607' | Source: 'Toledo OH 43607'
# (828) | ✅ MATCH (City, State, ZIP) | Extracted: 'Seattle, WA 98101' | Existing: 'Seattle, WA 98101' | Source: 'Seattle WA 98101'
# (829) | ✅ MATCH (City, State, ZIP) | Extracted: 'Carlsbad, CA 92008' | Existing: 'Carlsbad, CA 92008' | Source: 'Carlsbad CA 92008'
# (830) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94111' | Existing: 'San Francisco, CA 94111' | Source: 'San Francisco CA 94111'
# (831) | --- SKIPPED --- (Source is NaN)
# (832) | --- SKIPPED --- (Source is NaN)
# (833) | --- SKIPPED --- (Source is NaN)
# (834) | --- SKIPPED --- (Source is NaN)
# (835) | ✅ MATCH (City, State, ZIP) | Extracted: 'Santa Clara, CA 95051' | Existing: 'Santa Clara, CA 95051' | Source: 'Santa Clara CA 95051'
# (836) | --- SKIPPED --- (Source is NaN)
# (837) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Mateo, CA 94402' | Existing: 'San Mateo, CA 94402' | Source: 'San Mateo CA 94402'
# (838) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Mateo, CA 94401' | Existing: 'San Mateo, CA 94401' | Source: 'San Mateo CA 94401'
# (839) | --- SKIPPED --- (Source is NaN)
# (840) | --- SKIPPED --- (Source is NaN)
# (841) | --- SKIPPED --- (Source is NaN)
# (842) | --- SKIPPED --- (Source is NaN)
# (843) | ✅ MATCH (City, State, ZIP) | Extracted: 'Westport, CT 6880' | Existing: 'Westport, CT 6880' | Source: 'Westport CT 6880'
# (844) | ✅ MATCH (City, State, ZIP) | Extracted: 'Seattle, WA 98109' | Existing: 'Seattle, WA 98109' | Source: 'Seattle WA 98109'
# (845) | --- SKIPPED --- (Source is NaN)
# (846) | --- SKIPPED --- (Source is NaN)
# (847) | --- SKIPPED --- (Source is NaN)
# (848) | --- SKIPPED --- (Source is NaN)
# (849) | ✅ MATCH (City, State, ZIP) | Extracted: 'Chelmsford, MA 1824' | Existing: 'Chelmsford, MA 1824' | Source: 'Chelmsford MA 1824'
# (850) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94105' | Existing: 'San Francisco, CA 94105' | Source: 'San Francisco CA 94105'
# (851) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94107' | Existing: 'San Francisco, CA 94107' | Source: 'San Francisco CA 94107'
# (852) | ✅ MATCH (City, State, ZIP) | Extracted: 'Boulder, CO 80302' | Existing: 'Boulder, CO 80302' | Source: 'Boulder CO 80302'
# (853) | --- SKIPPED --- (Source is NaN)
# (854) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94103' | Existing: 'San Francisco, CA 94103' | Source: 'San Francisco CA 94103'
# (855) | ✅ MATCH (City, State, ZIP) | Extracted: 'Palo Alto, CA 94301' | Existing: 'Palo Alto, CA 94301' | Source: 'Palo Alto CA 94301'
# (856) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10010' | Existing: 'New York, NY 10010' | Source: 'New York NY 10010'
# (857) | --- SKIPPED --- (Source is NaN)
# (858) | --- SKIPPED --- (Source is NaN)
# (859) | ✅ MATCH (City, State, ZIP) | Extracted: 'Austin, TX 78746' | Existing: 'Austin, TX 78746' | Source: 'Austin TX 78746'
# (860) | --- SKIPPED --- (Source is NaN)
# (861) | --- SKIPPED --- (Source is NaN)
# (862) | ✅ MATCH (City, State, ZIP) | Extracted: 'Hampton, NJ 8827' | Existing: 'Hampton, NJ 8827' | Source: 'Hampton NJ 8827'
# (863) | ✅ MATCH (City, State, ZIP) | Extracted: 'Idaho Falls, ID 83402' | Existing: 'Idaho Falls, ID 83402' | Source: 'Idaho Falls ID 83402'
# (864) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Diego, CA 92121' | Existing: 'San Diego, CA 92121' | Source: 'San Diego CA 92121'
# (865) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94103' | Existing: 'San Francisco, CA 94103' | Source: 'San Francisco CA 94103'
# (866) | ❌ MISMATCH (City, State, ZIP ❌) | Extracted: 'Mountain View, CA 94040' | Existing: 'Mountain View, CA 94040-2573' | Source: 'Mountain View CA 94040-2573'
# (867) | --- SKIPPED --- (Source is NaN)
# (868) | ✅ MATCH (City, State, ZIP) | Extracted: 'Burlington, MA 1803' | Existing: 'Burlington, MA 1803' | Source: 'Burlington MA 1803'
# (869) | --- SKIPPED --- (Source is NaN)
# (870) | ✅ MATCH (City, State, ZIP) | Extracted: 'Acton, MA 1720' | Existing: 'Acton, MA 1720' | Source: 'Acton MA 1720'
# (871) | --- SKIPPED --- (Source is NaN)
# (872) | --- SKIPPED --- (Source is NaN)
# (873) | --- SKIPPED --- (Source is NaN)
# (874) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10011' | Existing: 'New York, NY 10011' | Source: 'New York NY 10011'
# (875) | ✅ MATCH (City, State, ZIP) | Extracted: 'Cambridge, MA 2139' | Existing: 'Cambridge, MA 2139' | Source: 'Cambridge MA 2139'
# (876) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Jose, CA 95134' | Existing: 'San Jose, CA 95134' | Source: 'San Jose CA 95134'
# (877) | --- SKIPPED --- (Source is NaN)
# (878) | --- SKIPPED --- (Source is NaN)
# (879) | ✅ MATCH (City, State, ZIP) | Extracted: 'La Jolla, CA 92037' | Existing: 'La Jolla, CA 92037' | Source: 'La Jolla CA 92037'
# (880) | --- SKIPPED --- (Source is NaN)
# (881) | --- SKIPPED --- (Source is NaN)
# (882) | ✅ MATCH (City, State, ZIP) | Extracted: 'Addison, TX 75001' | Existing: 'Addison, TX 75001' | Source: 'Addison TX 75001'
# (883) | --- SKIPPED --- (Source is NaN)
# (884) | --- SKIPPED --- (Source is NaN)
# (885) | --- SKIPPED --- (Source is NaN)
# (886) | ✅ MATCH (City, State, ZIP) | Extracted: 'Aliso Viejo, CA 92656' | Existing: 'Aliso Viejo, CA 92656' | Source: 'Aliso Viejo CA 92656'
# (887) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Francisco, CA 94110' | Existing: 'San Francisco, CA 94110' | Source: 'San Francisco CA 94110'
# (888) | ✅ MATCH (City, State, ZIP) | Extracted: 'Portland, OR 97224' | Existing: 'Portland, OR 97224' | Source: 'Portland OR 97224'
# (889) | --- SKIPPED --- (Source is NaN)
# (890) | ❌ MISMATCH (City, State, ZIP ❌) | Extracted: 'Palo Alto, CA 94301' | Existing: 'Palo Alto, CA 94301-1705' | Source: 'Palo Alto CA 94301-1705'
# (891) | --- SKIPPED --- (Source is NaN)
# (892) | ✅ MATCH (City, State, ZIP) | Extracted: 'Little Rock, AR 72201' | Existing: 'Little Rock, AR 72201' | Source: 'Little Rock AR 72201'
# (893) | --- SKIPPED --- (Source is NaN)
# (894) | ✅ MATCH (City, State, ZIP) | Extracted: 'Cambridge, MA 2142' | Existing: 'Cambridge, MA 2142' | Source: 'Cambridge MA 2142'
# (895) | --- SKIPPED --- (Source is NaN)
# (896) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10010' | Existing: 'New York, NY 10010' | Source: 'New York NY 10010'
# (897) | --- SKIPPED --- (Source is NaN)
# (898) | --- SKIPPED --- (Source is NaN)
# (899) | --- SKIPPED --- (Source is NaN)
# (900) | --- SKIPPED --- (Source is NaN)
# (901) | ✅ MATCH (City, State, ZIP) | Extracted: 'Palo Alto, CA 94303' | Existing: 'Palo Alto, CA 94303' | Source: 'Palo Alto CA 94303'
# (902) | --- SKIPPED --- (Source is NaN)
# (903) | ✅ MATCH (City, State, ZIP) | Extracted: 'Santa Clara, CA 95051' | Existing: 'Santa Clara, CA 95051' | Source: 'Santa Clara CA 95051'
# (904) | ✅ MATCH (City, State, ZIP) | Extracted: 'Houston, TX 77046' | Existing: 'Houston, TX 77046' | Source: 'Houston TX 77046'
# (905) | ✅ MATCH (City, State, ZIP) | Extracted: 'San Jose, CA 95110' | Existing: 'San Jose, CA 95110' | Source: 'San Jose CA 95110'
# (906) | --- SKIPPED --- (Source is NaN)
# (907) | --- SKIPPED --- (Source is NaN)
# (908) | --- SKIPPED --- (Source is NaN)
# (909) | --- SKIPPED --- (Source is NaN)
# (910) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10003' | Existing: 'New York, NY 10003' | Source: 'New York NY 10003'
# (911) | --- SKIPPED --- (Source is NaN)
# (912) | --- SKIPPED --- (Source is NaN)
# (913) | --- SKIPPED --- (Source is NaN)
# (914) | ✅ MATCH (City, State, ZIP) | Extracted: 'New York, NY 10001' | Existing: 'New York, NY 10001' | Source: 'New York NY 10001'
# (915) | --- SKIPPED --- (Source is NaN)
# (916) | --- SKIPPED --- (Source is NaN)
# (917) | --- SKIPPED --- (Source is NaN)
# (918) | --- SKIPPED --- (Source is NaN)
# (919) | ✅ MATCH (City, State, ZIP) | Extracted: 'Burlington, MA 1803' | Existing: 'Burlington, MA 1803' | Source: 'Burlington MA 1803'
# (920) | --- SKIPPED --- (Source is NaN)
# (921) | --- SKIPPED --- (Source is NaN)
# (922) | ✅ MATCH (City, State, ZIP) | Extracted: 'Santa Clara, CA 95054' | Existing: 'Santa Clara, CA 95054' | Source: 'Santa Clara CA 95054'
# --------------------------------------------------------------------------------------------------------------------------------------------
# Summary: 417 out of 430 non-null records fully matched.

# %% [markdown]
# ### States data
# - we have state_code ,'state_code.1', 'is_CA', 'is_NY', 'is_MA', 'is_TX', 'is_otherstate' columns related to the state
# - 'is_CA', 'is_NY', 'is_MA', 'is_TX', 'is_otherstate' seems to be a one-hot-encoded of the 'state_code'
# - 'state_code.1' is a copy of 'state_code' with a null value

# %%
df['state_code'].unique()
# Out:
# array(['CA', 'MA', 'KY', 'NY', 'CO', 'VA', 'TX', 'WA', 'IL', 'NC', 'PA',
#        'GA', 'NH', 'MO', 'FL', 'NJ', 'WV', 'MI', 'DC', 'CT', 'MD', 'OH',
#        'TN', 'MN', 'RI', 'OR', 'UT', 'ME', 'NV', 'NM', 'IN', 'AZ', 'ID',
#        'AR', 'WI'], dtype=object)

# %%
df['state_code.1'].unique()
# Out:
# array(['CA', 'MA', 'KY', 'NY', 'CO', 'VA', 'TX', 'WA', 'IL', 'NC', 'PA',
#        'GA', 'NH', 'MO', 'FL', 'NJ', 'WV', 'MI', 'DC', 'CT', 'MD', 'OH',
#        'TN', 'MN', 'RI', 'OR', 'UT', 'ME', 'NV', 'NM', 'IN', nan, 'AZ',
#        'ID', 'AR', 'WI'], dtype=object)

# %%
#check if it equals the state_code.1 column
non_null_mask = df['state_code'].notna() & df['state_code.1'].notna()

# Step 2: Compare values only at non-null locations
are_equal_at_non_null = df.loc[non_null_mask, 'state_code'] == df.loc[non_null_mask, 'state_code.1']

# Step 3: Check if all compared values are equal
result_col1_col2 = are_equal_at_non_null.all()
print(f"Are 'state_code' and 'state_code.1' equal (ignoring nulls)? {result_col1_col2}")
# Out:
# Are 'state_code' and 'state_code.1' equal (ignoring nulls)? True

# %%
# Define the states expected to have their own column
target_states = ['CA', 'NY', 'MA', 'TX']

# --- Step 1: Create the expected one-hot columns ---

# Create a Series that represents the 'other' state status
# Use .fillna('') to treat null state_codes as belonging to 'other' if they are not CA, NY, MA, or TX
is_other = ~df['state_code'].isin(target_states)

# Create a dictionary to hold the expected boolean results
expected_cols = {}

# Check individual target states
for state in target_states:
    # Check if state_code equals the target state
    expected_cols[f'is_{state}'] = (df['state_code'] == state)

# Check the 'is_otherstate' column
expected_cols['is_otherstate'] = is_other

# --- Step 2: Compare the existing and expected columns ---

# Initialize a check status dictionary
ohe_check_status = {
    'total_rows': len(df),
    'is_ohe_valid': True,
    'mismatches_by_column': {}
}

# Compare and count mismatches
for col_name, expected_series in expected_cols.items():
    # Ensure the expected boolean series matches the existing OHE column
    # Use .astype(bool) on the existing column to handle integer (0/1) or string ('True'/'False') representations
    existing_series = df[col_name].astype(bool)

    mismatches = (existing_series != expected_series).sum()
    ohe_check_status['mismatches_by_column'][col_name] = mismatches

    if mismatches > 0:
        ohe_check_status['is_ohe_valid'] = False

# --- Step 3: Print the results ---

print("==One-Hot Encoding Validation Results==")
print("---")
print(f"Total Records Checked:   {ohe_check_status['total_rows']}")
print(f"Overall Validation Status:  {'✅ Confirmed' if ohe_check_status['is_ohe_valid'] else '❌ Mismatches Found'}")
print("---")
print("  Mismatches by OHE Column:")
for col, count in ohe_check_status['mismatches_by_column'].items():
    print(f"- {col}: {count} mismatches")

# Optional: Check the row sum (a good OHE property)
# The sum of all OHE columns should equal 1 for every non-null state_code row
row_sum_check = df[['is_CA', 'is_NY', 'is_MA', 'is_TX', 'is_otherstate']].sum(axis=1)
rows_not_summing_to_one = (row_sum_check != 1).sum()

print("\nAdditional Check (Row Sum):")
print(f" Number of rows where OHE columns do NOT sum to 1: {rows_not_summing_to_one} (Ideally 0 for full coverage)")
# Out:
# ==One-Hot Encoding Validation Results==
# ---
# Total Records Checked:   923
# Overall Validation Status:  ❌ Mismatches Found
# ---
#   Mismatches by OHE Column:
# - is_CA: 1 mismatches
# - is_NY: 0 mismatches
# - is_MA: 0 mismatches
# - is_TX: 0 mismatches
# - is_otherstate: 0 mismatches
#
# Additional Check (Row Sum):
#  Number of rows where OHE columns do NOT sum to 1: 1 (Ideally 0 for full coverage)

# %% [markdown]
# ### category code
# - this is the category
# - 'is_software',  'is_web', 'is_mobile', 'is_enterprise', 'is_advertising',
#     'is_gamesvideo', 'is_ecommerce', 'is_biotech', 'is_consulting',
#     'is_othercategory' are OHE of the column

# %%
df['category_code'].unique()
# Out:
# array(['music', 'enterprise', 'web', 'software', 'games_video',
#        'network_hosting', 'finance', 'mobile', 'education',
#        'public_relations', 'security', 'other', 'photo_video', 'hardware',
#        'ecommerce', 'advertising', 'travel', 'fashion', 'analytics',
#        'consulting', 'biotech', 'cleantech', 'search', 'semiconductor',
#        'social', 'medical', 'automotive', 'messaging', 'manufacturing',
#        'hospitality', 'news', 'transportation', 'sports', 'real_estate',
#        'health'], dtype=object)

# %% [markdown]
# ### Age evaluation
# - age first funding year is the age of the company in years since it got first funding. similar for age last funding year
# - knowing this, the columns that start with "age" should not include negetive values (unless it was funded to be found)
# - However, in the data description all the 4 columns [age_first_funding_year, age_last_funding_year, age_first_milestone_year, age_last_milestone_year] min value is negative
# - precise_year_diff shows how the age was calculated, we still have many negative values which may indecate that the founded_at date is not accurate

# %%
df[['age_first_funding_year', 'age_last_funding_year', 'age_first_milestone_year', 'age_last_milestone_year']].describe()
# Out:
#        age_first_funding_year  age_last_funding_year  \
# count              923.000000             923.000000
# mean                 2.235630               3.931456
# std                  2.510449               2.967910
# min                 -9.046600              -9.046600
# 25%                  0.576700               1.669850
# 50%                  1.446600               3.528800
# 75%                  3.575350               5.560250
# max                 21.895900              21.895900
#
#        age_first_milestone_year  age_last_milestone_year
# count                771.000000               771.000000
# mean                   3.055353                 4.754423
# std                    2.977057                 3.212107
# min                  -14.169900                -7.005500
# 25%                    1.000000                 2.411000
# 50%                    2.520500                 4.476700
# 75%                    4.686300                 6.753400
# max                   24.684900                24.684900

# %%
df[df['age_first_funding_year'] <= 0]
# Out:
#      Unnamed: 0 state_code   latitude   longitude zip_code        id  \
# 4          1002         CA  37.779281 -122.419236    94105   c:65806
# 23           26         CA  37.764395 -122.401024    94103   c:10751
# 32          485         NC  36.002893  -78.904075    27701   c:27741
# 33          145         CA  37.779281 -122.419236    94105  c:150658
# 39           63         NY  40.755446  -73.980246    10010    c:1224
# ..          ...        ...        ...         ...      ...       ...
# 889         686         CA  37.504764 -122.259568    94085    c:3950
# 897          99         CA  32.938892 -117.239859    92130   c:13734
# 900        1089         CO  40.016210 -105.281310    80302     c:815
# 902         191         CA  37.316790 -122.050790    95014   c:16178
# 916         284         NY  40.742953  -73.984461    10018   c:17758
#
#               city              Unnamed: 6                    name  labels  \
# 4    San Francisco  San Francisco CA 94105          Inhale Digital       0
# 23   San Francisco                     NaN               Pixelpipe       0
# 32          Durham                     NaN                  eMinor       0
# 33   San Francisco  San Francisco CA 94105                   Karma       1
# 39        New York                     NaN                  Peer39       1
# ..             ...                     ...                     ...     ...
# 889      Sunnyvale                     NaN                 Cotendo       1
# 897      San Diego                     NaN  Imagine Communications       1
# 900        Boulder                     NaN                 OneRiot       1
# 902      Cupertino                     NaN                ArcSight       1
# 916       New York                     NaN                 TRAFFIQ       1
#
#      ... object_id has_VC has_angel has_roundA  has_roundB  has_roundC  \
# 4    ...   c:65806      1         1          0           0           0
# 23   ...   c:10751      0         1          1           0           0
# 32   ...   c:27741      0         0          1           1           0
# 33   ...  c:150658      1         0          0           0           0
# 39   ...    c:1224      1         1          1           1           1
# ..   ...       ...    ...       ...        ...         ...         ...
# 889  ...    c:3950      0         0          1           1           1
# 897  ...   c:13734      1         0          1           1           0
# 900  ...     c:815      0         0          1           1           1
# 902  ...   c:16178      0         0          1           1           1
# 916  ...   c:17758      1         0          1           1           0
#
#      has_roundD  avg_participants  is_top500    status
# 4             0            1.0000          1    closed
# 23            0            2.0000          0    closed
# 32            0            2.5000          1    closed
# 33            0            5.0000          1  acquired
# 39            0            2.7500          1  acquired
# ..          ...               ...        ...       ...
# 889           1            3.0000          1  acquired
# 897           0            2.2500          1  acquired
# 900           0            3.0000          1  acquired
# 902           0            6.0000          1  acquired
# 916           0            2.3333          1  acquired
#
# [102 rows x 49 columns]

# %%
df[df['age_last_funding_year'] <= 0]
# Out:
#      Unnamed: 0 state_code   latitude   longitude    zip_code        id  \
# 71          315         CA  37.349210 -122.032602       94087  c:190214
# 167         159         TN  35.149022  -90.051628  38103-4717  c:155621
# 201         906         IL  41.817807  -88.173402       60555   c:55044
# 207        1147         CA  26.052461  -80.137881       95037    c:9730
# 223        1050         CA  37.779281 -122.419236       94105   c:75500
# 234        1032         CA  37.465645 -121.932202       94538      c:72
# 249         437         NY  40.723652  -73.985281       10016    c:2566
# 263         891         UT  40.767013 -111.890431       84124   c:53831
# 283         246         CA  34.430786 -119.715074       93101   c:17030
# 284          88         CA  37.448944 -122.161415       94301   c:13358
# 300         876         TX  30.280148  -97.749908       78701   c:51969
# 336         148         CA  37.794891 -122.397901       94111   c:15129
# 340        1113         CA  37.388077 -122.083160       94041      c:86
# 417         199         NY  40.752516  -73.973072       10017    c:1627
# 431         886         CA  34.066697 -118.383367       90211   c:53304
# 432         314         CT  54.983201   -1.574631        6103    c:1899
# 468         144         OH  39.099909  -84.504243       45202  c:150577
# 489         325         CA  37.550954 -122.315396       94303    c:1957
# 536          69         WA  47.603327 -122.334983       98104    c:1253
# 558         372         NY  40.743662  -73.984268       10016    c:2245
# 567         839         CA  37.814202 -122.477959       94025    c:4881
# 603         990         CA  37.779281 -122.419236       94105   c:63731
# 702         118         DC  38.894955  -77.036646       20005  c:144631
# 721         361         CA  37.777678 -122.392110       94107    c:2178
# 748        1024         NY  40.728425  -73.999882       10012   c:70661
# 785         830         NY  40.759089  -73.987573       10036   c:47662
# 787         941         OH  39.962260  -83.000706       43207   c:58696
# 839         976         CA  33.831671 -118.315766       90501    c:6219
# 840         669         CA  37.755068 -122.418026       94110   c:38337
# 842         122         FL  28.666770  -81.392794       32714   c:14483
#
#                   city               Unnamed: 6                   name  \
# 71           Sunnyvale                      NaN                Behavio
# 167            Memphis    Memphis TN 38103-4717           Friendsignia
# 201        Warrenville     Warrenville IL 60555  ezzai - how to arabia
# 207        Morgan Hill                      NaN            OfferLounge
# 223      San Francisco   San Francisco CA 94105              Solmentum
# 234            Fremont                      NaN           GrandCentral
# 249           New York                      NaN                Kluster
# 263     Salt Lake City  Salt Lake City UT 84124                 Inaura
# 283      Santa Barbara                      NaN         SendMeHome.com
# 284          Palo Alto                      NaN                Q-magic
# 300             Austin          Austin TX 78701        Hurricane Party
# 336       San Franciso                      NaN                Zentact
# 340      Mountain View                      NaN           Zing Systems
# 417           New York                      NaN                 WeShow
# 431      Beverly Hills   Beverly Hills CA 90211             GeekStatus
# 432           Hartford         Hartford CT 6103                   MOLI
# 468         Cincinnati      Cincinnati OH 45202               StyleZen
# 489          Palo Alto                      NaN            Sharetivity
# 536            Seattle                      NaN                  Faves
# 558           New York                      NaN              Advaliant
# 567         Menlo Park                      NaN            Syncplicity
# 603      San Francisco   San Francisco CA 94105            Weatherista
# 702         Washington      Washington DC 20005     VeteranCentral.com
# 721      San Francisco                      NaN         What They Like
# 748           New York        New York NY 10012              StyleTrek
# 785           New York        New York NY 10036             SpinTheCam
# 787           Columbus        Columbus OH 43207                 Dormzy
# 839           Torrance                      NaN               DotSpots
# 840      San Francisco                      NaN               about.me
# 842  Altamonte Springs                      NaN            Hit Systems
#
#      labels  ... object_id has_VC has_angel has_roundA  has_roundB  \
# 71        1  ...  c:190214      0         1          0           0
# 167       0  ...  c:155621      0         1          0           0
# 201       0  ...   c:55044      0         0          0           0
# 207       0  ...    c:9730      0         1          0           0
# 223       0  ...   c:75500      0         1          0           0
# 234       1  ...      c:72      0         0          1           0
# 249       1  ...    c:2566      0         1          0           0
# 263       0  ...   c:53831      1         0          0           0
# 283       0  ...   c:17030      0         1          0           0
# 284       0  ...   c:13358      0         1          0           0
# 300       0  ...   c:51969      0         1          0           0
# 336       0  ...   c:15129      0         1          0           0
# 340       1  ...      c:86      0         0          1           0
# 417       0  ...    c:1627      0         0          1           0
# 431       0  ...   c:53304      0         1          0           0
# 432       0  ...    c:1899      0         0          1           1
# 468       0  ...  c:150577      0         1          0           0
# 489       0  ...    c:1957      0         0          0           0
# 536       0  ...    c:1253      0         0          0           0
# 558       0  ...    c:2245      0         1          0           0
# 567       1  ...    c:4881      0         0          1           0
# 603       0  ...   c:63731      0         1          0           0
# 702       0  ...  c:144631      0         1          0           0
# 721       0  ...    c:2178      0         0          1           0
# 748       0  ...   c:70661      0         0          0           0
# 785       0  ...   c:47662      0         1          0           0
# 787       0  ...   c:58696      0         1          0           0
# 839       0  ...    c:6219      0         1          0           0
# 840       1  ...   c:38337      1         0          0           0
# 842       0  ...   c:14483      0         1          0           0
#
#      has_roundC  has_roundD  avg_participants  is_top500    status
# 71            0           0               1.0          0  acquired
# 167           0           0               1.0          0    closed
# 201           0           0               2.0          0    closed
# 207           0           0               2.0          0    closed
# 223           0           0               4.0          0    closed
# 234           0           0               1.0          0  acquired
# 249           0           0               1.0          1  acquired
# 263           0           0               1.0          0    closed
# 283           0           0               2.0          0    closed
# 284           0           0               1.0          0    closed
# 300           0           0               1.0          0    closed
# 336           0           0               3.0          0    closed
# 340           1           0               2.5          1  acquired
# 417           0           0               2.0          0    closed
# 431           0           0               1.0          0    closed
# 432           0           0               2.0          0    closed
# 468           0           0               1.0          0    closed
# 489           0           0               1.0          0    closed
# 536           0           0               3.0          0    closed
# 558           0           0               1.0          0    closed
# 567           0           0               2.0          1  acquired
# 603           0           0               1.0          0    closed
# 702           0           0               1.0          0    closed
# 721           0           0               2.0          0    closed
# 748           0           0               6.0          1    closed
# 785           0           0               1.0          0    closed
# 787           0           0               1.0          0    closed
# 839           0           0               2.0          0    closed
# 840           0           0               4.0          1  acquired
# 842           0           0               1.0          0    closed
#
# [30 rows x 49 columns]

# %% [markdown]
# #### Recalculting the age funding year

# %%
df['founded_at'] = pd.to_datetime(df['founded_at'], errors='coerce')
df['first_funding_at'] = pd.to_datetime(df['first_funding_at'], errors='coerce')
year_diff = df['first_funding_at'].dt.year - df['founded_at'].dt.year
year_diff
# Out:
# 0      2
# 1      5
# 2      1
# 3      3
# 4      0
#       ..
# 918    0
# 919    7
# 920    8
# 921    0
# 922    3
# Length: 923, dtype: int64

# %%
# 16 values are less than zero, this may indecate an error in data entering
df[year_diff < 0]
# Out:
#     state_code   latitude   longitude zip_code            city  \
# 23          CA  37.764395 -122.401024    94103   San Francisco
# 127         PA  40.441694  -79.990086    15213      Pittsburgh
# 240         CA  37.406914 -122.090370    94043   Mountain View
# 263         UT  40.767013 -111.890431    84124  Salt Lake City
# 340         CA  37.388077 -122.083160    94041   Mountain View
# 379         MA  42.360253  -71.058291     2114          Boston
# 420         CA  32.889450 -117.166929    92121       San Diego
# 431         CA  34.066697 -118.383367    90211   Beverly Hills
# 432         CT  54.983201   -1.574631     6103        Hartford
# 489         CA  37.550954 -122.315396    94303       Palo Alto
# 499         CA  37.437328 -122.159928    94303       Palo Alto
# 558         NY  40.743662  -73.984268    10016        New York
# 584         MA  42.358956  -71.054776     2109          Boston
# 788         CA  34.144926 -118.149767    91105        Pasadena
# 831         NY  40.707645  -74.010816    10038        New York
# 847         RI  41.818712  -71.411775     2903      Providence
#
#                    name  labels founded_at   closed_at first_funding_at  ...  \
# 23            Pixelpipe       0 2008-01-01    8/2/2013       2007-01-01  ...
# 127               Bueda       0 2009-01-04    6/1/2013       2008-01-01  ...
# 240                UpMo       0 2011-01-01    7/1/2013       2009-12-13  ...
# 263              Inaura       0 2007-01-01   7/19/2012       2005-01-06  ...
# 340        Zing Systems       1 2007-06-01         NaN       2006-12-01  ...
# 379               Where       1 2004-01-01         NaN       2003-12-31  ...
# 420      Tapioca Mobile       0 2008-01-01    7/9/2012       2007-09-01  ...
# 431          GeekStatus       0 2010-08-01    6/1/2013       2009-02-10  ...
# 432                MOLI       0 2008-01-01   5/24/2010       2007-01-01  ...
# 489         Sharetivity       0 2007-07-07  11/11/2012       2006-05-01  ...
# 499          MyMiniLife       1 2007-01-01         NaN       2006-11-15  ...
# 558           Advaliant       0 2013-04-16    5/4/2009       2004-04-01  ...
# 584       Swaptree Inc.       0 2010-01-01    5/1/2013       2006-07-01  ...
# 788             iChange       1 2008-01-01         NaN       2007-10-01  ...
# 831            Correlix       0 2006-01-01    5/1/2013       2005-02-19  ...
# 847  MoveableCode, Inc.       0 2010-01-01   1/14/2012       2009-01-01  ...
#
#        category_code  has_VC  has_angel  has_roundA  has_roundB  has_roundC  \
# 23            mobile       0          1           1           0           0
# 127      advertising       1          1           0           0           0
# 240       enterprise       1          0           0           0           0
# 263            other       1          0           0           0           0
# 340      games_video       0          0           1           0           1
# 379           mobile       0          0           1           1           1
# 420           mobile       1          1           0           0           0
# 431              web       0          1           0           0           0
# 432  network_hosting       0          0           1           1           0
# 489              web       0          0           0           0           0
# 499      games_video       0          1           0           0           0
# 558      advertising       0          1           0           0           0
# 584              web       1          0           0           1           1
# 788           health       0          1           1           0           0
# 831       enterprise       1          0           0           1           0
# 847           mobile       0          1           0           0           0
#
#      has_roundD  avg_participants  is_top500    status
# 23            0            2.0000          0    closed
# 127           0            1.0000          1    closed
# 240           0            3.0000          0    closed
# 263           0            1.0000          0    closed
# 340           0            2.5000          1  acquired
# 379           0            2.5000          1  acquired
# 420           0            1.0000          1    closed
# 431           0            1.0000          0    closed
# 432           0            2.0000          0    closed
# 489           0            1.0000          0    closed
# 499           0            1.6667          0  acquired
# 558           0            1.0000          0    closed
# 584           0            1.0000          1    closed
# 788           0            2.0000          0  acquired
# 831           0            3.0000          1    closed
# 847           0            1.0000          1    closed
#
# [16 rows x 29 columns]

# %%
time_difference = df['first_funding_at'] - df['founded_at']
precise_year_diff = time_difference.dt.days / 365
precise_year_diff
# Out:
# 0      2.249315
# 1      5.126027
# 2      1.032877
# 3      3.131507
# 4      0.000000
#          ...
# 918    0.517808
# 919    7.252055
# 920    8.495890
# 921    0.758904
# 922    3.120548
# Length: 923, dtype: float64

# %%
df[precise_year_diff < 0]
# Out:
#     state_code   latitude   longitude zip_code            city  \
# 23          CA  37.764395 -122.401024    94103   San Francisco
# 32          NC  36.002893  -78.904075    27701          Durham
# 71          CA  37.349210 -122.032602    94087       Sunnyvale
# 79          MA  42.375100  -71.105616     2138       Cambridge
# 80          CA  37.779281 -122.419236    94105   San Francisco
# 104         CA  37.748676 -122.415813    94110   San Francisco
# 122         TX  40.694599  -73.990638    78701          Austin
# 127         PA  40.441694  -79.990086    15213      Pittsburgh
# 234         CA  37.465645 -121.932202    94538         Fremont
# 240         CA  37.406914 -122.090370    94043   Mountain View
# 263         UT  40.767013 -111.890431    84124  Salt Lake City
# 284         CA  37.448944 -122.161415    94301       Palo Alto
# 312         CA  37.778613 -122.395289    94107   San Francisco
# 340         CA  37.388077 -122.083160    94041   Mountain View
# 368         CA  33.685697 -117.825982    92612          Irvine
# 379         MA  42.360253  -71.058291     2114          Boston
# 382         CA  37.779281 -122.419236    94103   San Francisco
# 397         NY  37.809782 -122.417306    10003        New York
# 407         NY  40.729839  -73.991781    10003        New York
# 420         CA  32.889450 -117.166929    92121       San Diego
# 431         CA  34.066697 -118.383367    90211   Beverly Hills
# 432         CT  54.983201   -1.574631     6103        Hartford
# 466         CA  37.775206 -122.419209    94107   San Francisco
# 488         CA  37.387845 -122.055197    94089       Sunnyvale
# 489         CA  37.550954 -122.315396    94303       Palo Alto
# 499         CA  37.437328 -122.159928    94303       Palo Alto
# 513         NY  40.743808  -73.983626    10010        New York
# 518         CA  37.563585 -122.324621    94043   Mountain View
# 536         WA  47.603327 -122.334983    98104         Seattle
# 558         NY  40.743662  -73.984268    10016        New York
# 566         KY  38.046407  -84.497039    40507       Lexington
# 567         CA  37.814202 -122.477959    94025      Menlo Park
# 584         MA  42.358956  -71.054776     2109          Boston
# 603         CA  37.779281 -122.419236    94105   San Francisco
# 609         CA  37.406302 -122.108874    94040   Mountain View
# 702         DC  38.894955  -77.036646    20005      Washington
# 720         TX  30.280148  -97.749908    78701          Austin
# 763         CA  37.779281 -122.419236    94110   San Francisco
# 782         UT  40.233844 -111.658534    84087           Provo
# 785         NY  40.759089  -73.987573    10036        New York
# 788         CA  34.144926 -118.149767    91105        Pasadena
# 830         CA  37.779281 -122.419236    94111   San Francisco
# 831         NY  40.707645  -74.010816    10038        New York
# 847         RI  41.818712  -71.411775     2903      Providence
# 851         CA  37.779281 -122.419236    94107   San Francisco
# 875         MA  42.375100  -71.105616     2139       Cambridge
#
#                     name  labels founded_at   closed_at first_funding_at  ...  \
# 23             Pixelpipe       0 2008-01-01    8/2/2013       2007-01-01  ...
# 32                eMinor       0 2006-10-01   2/17/2012       2006-08-01  ...
# 71               Behavio       1 2012-06-12         NaN       2012-06-01  ...
# 79             AccelGolf       0 2008-08-01    5/1/2013       2008-01-01  ...
# 80                 MoPub       1 2010-09-09         NaN       2010-09-01  ...
# 104             Aardvark       1 2007-07-01    9/1/2011       2007-01-01  ...
# 122         Workstreamer       0 2009-10-01    6/1/2013       2009-01-01  ...
# 127                Bueda       0 2009-01-04    6/1/2013       2008-01-01  ...
# 234         GrandCentral       1 2006-04-01         NaN       2006-01-01  ...
# 240                 UpMo       0 2011-01-01    7/1/2013       2009-12-13  ...
# 263               Inaura       0 2007-01-01   7/19/2012       2005-01-06  ...
# 284              Q-magic       0 2007-02-01  11/29/2011       2007-01-01  ...
# 312             Powerset       1 2006-10-01         NaN       2006-05-01  ...
# 340         Zing Systems       1 2007-06-01         NaN       2006-12-01  ...
# 368             PayDivvy       1 2009-03-06         NaN       2009-01-15  ...
# 379                Where       1 2004-01-01         NaN       2003-12-31  ...
# 382              Storify       1 2009-12-11         NaN       2009-07-01  ...
# 397             Surphace       1 2005-06-01         NaN       2005-04-01  ...
# 407  The Huffington Post       1 2005-05-09         NaN       2005-05-01  ...
# 420       Tapioca Mobile       0 2008-01-01    7/9/2012       2007-09-01  ...
# 431           GeekStatus       0 2010-08-01    6/1/2013       2009-02-10  ...
# 432                 MOLI       0 2008-01-01   5/24/2010       2007-01-01  ...
# 466             threadsy       1 2008-06-01         NaN       2008-03-27  ...
# 488                Plaxo       1 2002-11-17         NaN       2002-11-01  ...
# 489          Sharetivity       0 2007-07-07  11/11/2012       2006-05-01  ...
# 499           MyMiniLife       1 2007-01-01         NaN       2006-11-15  ...
# 513    Next New Networks       1 2007-03-01         NaN       2007-01-01  ...
# 518                AdMob       1 2006-12-01         NaN       2006-09-01  ...
# 536                Faves       0 2004-12-01  12/31/2011       2004-01-01  ...
# 558            Advaliant       0 2013-04-16    5/4/2009       2004-04-01  ...
# 566         AwesomeTouch       1 2010-07-26         NaN       2010-04-30  ...
# 567          Syncplicity       1 2008-11-03         NaN       2008-10-31  ...
# 584        Swaptree Inc.       0 2010-01-01    5/1/2013       2006-07-01  ...
# 603          Weatherista       0 2010-08-16    9/1/2012       2010-08-15  ...
# 609         HighlightCam       0 2009-07-27  10/30/2013       2009-06-01  ...
# 702   VeteranCentral.com       0 2011-12-15    7/1/2013       2011-06-15  ...
# 720         MapMyFitness       1 2007-02-08         NaN       2007-01-01  ...
# 763         1000memories       1 2010-07-01         NaN       2010-01-01  ...
# 782       Tipping Bucket       0 2009-04-08    1/1/2012       2009-04-01  ...
# 785           SpinTheCam       0 2010-02-12   2/17/2012       2010-01-01  ...
# 788              iChange       1 2008-01-01         NaN       2007-10-01  ...
# 830              Cohuman       1 2009-10-09         NaN       2009-09-09  ...
# 831             Correlix       0 2006-01-01    5/1/2013       2005-02-19  ...
# 847   MoveableCode, Inc.       0 2010-01-01   1/14/2012       2009-01-01  ...
# 851                 Opzi       0 2010-05-01    7/1/2013       2010-01-01  ...
# 875         Bluefin Labs       1 2008-06-01         NaN       2008-04-01  ...
#
#         category_code  has_VC  has_angel  has_roundA  has_roundB  has_roundC  \
# 23             mobile       0          1           1           0           0
# 32           software       0          0           1           1           0
# 71           software       0          1           0           0           0
# 79             mobile       1          1           0           0           0
# 80             mobile       0          1           1           1           0
# 104               web       0          1           1           0           0
# 122        enterprise       0          1           1           0           0
# 127       advertising       1          1           0           0           0
# 234            mobile       0          0           1           0           0
# 240        enterprise       1          0           0           0           0
# 263             other       1          0           0           0           0
# 284  public_relations       0          1           0           0           0
# 312            search       1          0           1           0           0
# 340       games_video       0          0           1           0           1
# 368            social       0          1           0           0           0
# 379            mobile       0          0           1           1           1
# 382               web       0          1           1           0           0
# 397               web       0          0           1           1           0
# 407              news       1          0           1           1           1
# 420            mobile       1          1           0           0           0
# 431               web       0          1           0           0           0
# 432   network_hosting       0          0           1           1           0
# 466         messaging       0          0           1           1           0
# 488               web       0          0           1           1           1
# 489               web       0          0           0           0           0
# 499       games_video       0          1           0           0           0
# 513               web       0          0           1           1           1
# 518       advertising       0          0           1           1           1
# 536               web       0          0           0           0           0
# 558       advertising       0          1           0           0           0
# 566          software       0          1           0           0           0
# 567        enterprise       0          0           1           0           0
# 584               web       1          0           0           1           1
# 603               web       0          1           0           0           0
# 609            mobile       0          1           1           0           0
# 702            social       0          1           0           0           0
# 720            health       1          0           1           1           1
# 763               web       0          1           1           0           0
# 782        enterprise       0          1           0           0           0
# 785       games_video       0          1           0           0           0
# 788            health       0          1           1           0           0
# 830        enterprise       0          1           0           0           0
# 831        enterprise       1          0           0           1           0
# 847            mobile       0          1           0           0           0
# 851       games_video       0          1           0           0           0
# 875         analytics       0          1           1           1           0
#
#      has_roundD  avg_participants  is_top500    status
# 23            0            2.0000          0    closed
# 32            0            2.5000          1    closed
# 71            0            1.0000          0  acquired
# 79            0            1.0000          1    closed
# 80            0            2.2500          1  acquired
# 104           0            4.0000          1  acquired
# 122           0            1.0000          1    closed
# 127           0            1.0000          1    closed
# 234           0            1.0000          0  acquired
# 240           0            3.0000          0    closed
# 263           0            1.0000          0    closed
# 284           0            1.0000          0    closed
# 312           0            4.0000          1  acquired
# 340           0            2.5000          1  acquired
# 368           0            1.0000          0  acquired
# 379           0            2.5000          1  acquired
# 382           0            1.3333          1  acquired
# 397           0            5.5000          1  acquired
# 407           0            2.5000          1  acquired
# 420           0            1.0000          1    closed
# 431           0            1.0000          0    closed
# 432           0            2.0000          0    closed
# 466           0            2.0000          1  acquired
# 488           1            2.5000          1  acquired
# 489           0            1.0000          0    closed
# 499           0            1.6667          0  acquired
# 513           0            3.5000          1  acquired
# 518           0            2.5000          1  acquired
# 536           0            3.0000          0    closed
# 558           0            1.0000          0    closed
# 566           0            1.0000          1  acquired
# 567           0            2.0000          1  acquired
# 584           0            1.0000          1    closed
# 603           0            1.0000          0    closed
# 609           0            3.5000          1    closed
# 702           0            1.0000          0    closed
# 720           0            1.7500          1  acquired
# 763           0            5.0000          1  acquired
# 782           0            1.0000          0    closed
# 785           0            1.0000          0    closed
# 788           0            2.0000          0  acquired
# 830           0            3.0000          0  acquired
# 831           0            3.0000          1    closed
# 847           0            1.0000          1    closed
# 851           0            5.0000          1    closed
# 875           0            3.7500          1  acquired
#
# [46 rows x 29 columns]

# %%
(df['age_first_funding_year'] - precise_year_diff).abs().sum()
# Out:
# 0.02178767123287831

# %% [markdown]
# ### Fundings

# %%
df[['funding_rounds', 'has_VC', 'has_angel', 'has_roundA', 'has_roundB', 'has_roundC', 'has_roundD']]
# Out:
#      funding_rounds  has_VC  has_angel  has_roundA  has_roundB  has_roundC  \
# 0                 3       0          1           0           0           0
# 1                 4       1          0           0           1           1
# 2                 1       0          0           1           0           0
# 3                 3       0          0           0           1           1
# 4                 2       1          1           0           0           0
# ..              ...     ...        ...         ...         ...         ...
# 918               1       0          0           1           0           0
# 919               3       1          0           0           1           0
# 920               1       0          0           0           0           0
# 921               2       0          0           1           1           0
# 922               1       0          0           0           1           0
#
#      has_roundD
# 0             0
# 1             1
# 2             0
# 3             1
# 4             0
# ..          ...
# 918           0
# 919           0
# 920           1
# 921           0
# 922           0
#
# [923 rows x 7 columns]

# %%
df['milestones']
# Out:
# 0      3
# 1      1
# 2      2
# 3      1
# 4      1
#       ..
# 918    2
# 919    1
# 920    1
# 921    2
# 922    1
# Name: milestones, Length: 923, dtype: int64

# %% [markdown]
# # Dropping Columns

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'state_code', 'latitude', 'longitude', 'zip_code', 'id',
#        'city', 'Unnamed: 6', 'name', 'labels', 'founded_at', 'closed_at',
#        'first_funding_at', 'last_funding_at', 'age_first_funding_year',
#        'age_last_funding_year', 'age_first_milestone_year',
#        'age_last_milestone_year', 'relationships', 'funding_rounds',
#        'funding_total_usd', 'milestones', 'state_code.1', 'is_CA', 'is_NY',
#        'is_MA', 'is_TX', 'is_otherstate', 'category_code', 'is_software',
#        'is_web', 'is_mobile', 'is_enterprise', 'is_advertising',
#        'is_gamesvideo', 'is_ecommerce', 'is_biotech', 'is_consulting',
#        'is_othercategory', 'object_id', 'has_VC', 'has_angel', 'has_roundA',
#        'has_roundB', 'has_roundC', 'has_roundD', 'avg_participants',
#        'is_top500', 'status'],
#       dtype='object')

# %%
columns_to_drop=['Unnamed: 0', 'id', 'Unnamed: 6', 'state_code.1', 'is_CA', 'is_NY', 'is_MA', 'is_TX', 'is_otherstate', 'is_software',
       'is_web', 'is_mobile', 'is_enterprise', 'is_advertising',
       'is_gamesvideo', 'is_ecommerce', 'is_biotech', 'is_consulting', 'object_id',
       'is_othercategory']
df.drop(columns= columns_to_drop, inplace=True)
df
# Out:
#     state_code   latitude   longitude zip_code           city  \
# 0           CA  42.358880  -71.056820    92101      San Diego
# 1           CA  37.238916 -121.973718    95032      Los Gatos
# 2           CA  32.901049 -117.192656    92121      San Diego
# 3           CA  37.320309 -122.050040    95014      Cupertino
# 4           CA  37.779281 -122.419236    94105  San Francisco
# ..         ...        ...         ...      ...            ...
# 918         CA  37.740594 -122.376471    94107  San Francisco
# 919         MA  42.504817  -71.195611     1803     Burlington
# 920         CA  37.408261 -122.015920    94089      Sunnyvale
# 921         CA  37.556732 -122.288378    94404  San Francisco
# 922         CA  37.386778 -121.966277    95054    Santa Clara
#
#                      name  labels founded_at  closed_at first_funding_at  ...  \
# 0             Bandsintown       1   1/1/2007        NaN         4/1/2009  ...
# 1               TriCipher       1   1/1/2000        NaN        2/14/2005  ...
# 2                   Plixi       1  3/18/2009        NaN        3/30/2010  ...
# 3       Solidcore Systems       1   1/1/2002        NaN        2/17/2005  ...
# 4          Inhale Digital       0   8/1/2010  10/1/2012         8/1/2010  ...
# ..                    ...     ...        ...        ...              ...  ...
# 918               CoTweet       1   1/1/2009        NaN         7/9/2009  ...
# 919    Reef Point Systems       0   1/1/1998  6/25/2008         4/1/2005  ...
# 920       Paracor Medical       0   1/1/1999  6/17/2012        6/29/2007  ...
# 921               Causata       1   1/1/2009        NaN        10/5/2009  ...
# 922  Asempra Technologies       1   1/1/2003        NaN        2/13/2006  ...
#
#     category_code  has_VC  has_angel  has_roundA  has_roundB  has_roundC  \
# 0           music       0          1           0           0           0
# 1      enterprise       1          0           0           1           1
# 2             web       0          0           1           0           0
# 3        software       0          0           0           1           1
# 4     games_video       1          1           0           0           0
# ..            ...     ...        ...         ...         ...         ...
# 918   advertising       0          0           1           0           0
# 919      security       1          0           0           1           0
# 920       biotech       0          0           0           0           0
# 921      software       0          0           1           1           0
# 922      security       0          0           0           1           0
#
#      has_roundD  avg_participants  is_top500    status
# 0             0            1.0000          0  acquired
# 1             1            4.7500          1  acquired
# 2             0            4.0000          1  acquired
# 3             1            3.3333          1  acquired
# 4             0            1.0000          1    closed
# ..          ...               ...        ...       ...
# 918           0            6.0000          1  acquired
# 919           0            2.6667          1    closed
# 920           1            8.0000          1    closed
# 921           0            1.0000          1  acquired
# 922           0            3.0000          1  acquired
#
# [923 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['state_code', 'latitude', 'longitude', 'zip_code', 'city', 'name',
#        'labels', 'founded_at', 'closed_at', 'first_funding_at',
#        'last_funding_at', 'age_first_funding_year', 'age_last_funding_year',
#        'age_first_milestone_year', 'age_last_milestone_year', 'relationships',
#        'funding_rounds', 'funding_total_usd', 'milestones', 'category_code',
#        'has_VC', 'has_angel', 'has_roundA', 'has_roundB', 'has_roundC',
#        'has_roundD', 'avg_participants', 'is_top500', 'status'],
#       dtype='object')

# %%
df['founded_at']
# Out:
# 0       1/1/2007
# 1       1/1/2000
# 2      3/18/2009
# 3       1/1/2002
# 4       8/1/2010
#          ...
# 918     1/1/2009
# 919     1/1/1998
# 920     1/1/1999
# 921     1/1/2009
# 922     1/1/2003
# Name: founded_at, Length: 923, dtype: object
